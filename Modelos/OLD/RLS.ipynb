# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import statsmodels.api as sm
import scipy.stats as stats
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import mean_absolute_error
import seaborn as sns
from scipy.stats import norm

# %%
file_path = r"G:\Meu Drive\MESTRADO - MLOG\Projeto EV-Explore Ambev\TESTE_MAP_MATCHING_25_04\DATA_30_08_2024.xlsx"
data = pd.read_excel(file_path)

# %%
data
# Out:
#               ID_Rota  Energy_Estimated(%)  Distance_Traveled(km)  \
# 0    20230901_RHQ2H04            41.716498                   40.4
# 1    20230902_RHS6B08            47.357887                   49.6
# 2    20230902_RHS6F90            54.828160                   50.1
# 3    20230902_RHT4G96            45.270473                   54.3
# 4    20230904_RHQ2H05            70.687503                   57.8
# ..                ...                  ...                    ...
# 172  20240215_RHS6B06            44.577909                   41.9
# 173  20240220_RHS6F91            44.204194                   51.8
# 174  20240222_RHQ2H03            51.895367                   58.9
# 175  20240226_RHS6F92            59.709741                   54.6
# 176  20240228_RHO2C32            56.130937                   63.6
#
#      Avg_Temperature(C)  Air_Humidity(%)  Dist_Cluster_Clients(km)  \
# 0             22.144429        52.796897                 14.067360
# 1             22.191493        67.361194                  7.806090
# 2             23.431280        62.676540                 15.033330
# 3             19.594087        76.893316                 19.882506
# 4             27.653575        51.407254                 18.174622
# ..                  ...              ...                       ...
# 172           20.597115        88.774038                  1.555601
# 173           21.943542        83.979167                 12.778484
# 174           24.058857        73.000000                 11.092253
# 175           23.718381        75.708263                  8.025749
# 176           25.684865        68.520000                  9.268346
#
#      Route_Time(h)  Total_Weighted_Mass(ton)  Stdv_Altitudes(m)  \
# 0         3.185833                  8.094501           7.352432
# 1         2.211111                  9.206331           8.139739
# 2         3.123611                  8.473027          20.839832
# 3         3.283333                  7.848595          10.572484
# 4         3.598056                  9.276940          21.626044
# ..             ...                       ...                ...
# 172       2.258611                  9.974098          16.337546
# 173       2.440278                  9.663950           7.199588
# 174       2.813611                  8.282822          23.873651
# 175       3.442500                 10.503930           8.306538
# 176       5.407778                  8.645870          12.285459
#
#      Wind_Speed(m/s)  Avg_Speed(m/s)  Number_Deliveries  Rain(mm)  \
# 0           1.495487        3.524209                 10  0.000000
# 1           2.044776        6.244209                  8  0.000000
# 2           2.096801        4.455477                 13  0.000000
# 3           1.692545        4.597407                  9  0.000000
# 4           3.153472        4.485942                 11  0.000000
# ..               ...             ...                ...       ...
# 172         2.152644        5.198889                  8  0.083173
# 173         1.208125        5.905980                 14  0.120833
# 174         1.963810        5.817566                 12  0.000000
# 175         1.892749        4.403178                  8  0.000000
# 176         0.992216        3.273808                 11  0.878486
#
#      Max_Temp(C)  Real_Energy_Expenditure(%)
# 0           27.5                        41.2
# 1           29.6                        41.6
# 2           29.6                        46.4
# 3           24.0                        38.0
# 4           30.9                        52.4
# ..           ...                         ...
# 172         22.3                        36.8
# 173         23.8                        37.2
# 174         29.0                        53.2
# 175         26.5                        44.4
# 176         30.9                        56.0
#
# [177 rows x 15 columns]

# %%
X = data[['Energy_Estimated(%)']]
y = data['Real_Energy_Expenditure(%)']

X = sm.add_constant(X)

model = sm.OLS(y, X)

results = model.fit()

residuos = results.resid

print(results.summary())
# Out:
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     Real_Energy_Expenditure(%)   R-squared:                       0.699
# Model:                                    OLS   Adj. R-squared:                  0.697
# Method:                         Least Squares   F-statistic:                     405.6
# Date:                        Wed, 04 Sep 2024   Prob (F-statistic):           1.92e-47
# Time:                                09:58:57   Log-Likelihood:                -538.10
# No. Observations:                         177   AIC:                             1080.
# Df Residuals:                             175   BIC:                             1087.
# Df Model:                                   1
# Covariance Type:                    nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  12.8248      1.743      7.360      0.000       9.386      16.264
# Energy_Estimated(%)     0.6280      0.031     20.139      0.000       0.566       0.690
# ==============================================================================
# Omnibus:                        5.689   Durbin-Watson:                   1.961
# Prob(Omnibus):                  0.058   Jarque-Bera (JB):                5.377
# Skew:                           0.418   Prob(JB):                       0.0680
# Kurtosis:                       3.177   Cond. No.                         255.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
y_pred = results.predict(X)

# %%
intercept, slope = results.params

r_squared = results.rsquared

x_fit = np.linspace(0, data['Energy_Estimated(%)'].max(), 100)
y_fit = intercept + slope * x_fit

plt.figure(figsize=(10, 6))
plt.scatter(data['Energy_Estimated(%)'], data['Real_Energy_Expenditure(%)'], color='blue', label='Sample Points')

plt.plot(x_fit, y_fit, color='red', label='Regression line')

plt.xlabel('Estimated Energy Consumption - Exp. Regen. (%)')
plt.ylabel('Real Energy Consumption (%)')
plt.title('SLR: Estimated Energy Consumption - Exp. Regen. (%) vs. Real Energy Consumption (%)')

plt.xlim(left=0)
plt.ylim(bottom=0)

equation = f'Y = {intercept:.2f} + {slope:.2f}X'
r_squared_text = f'R² = {r_squared:.2f}'
plt.text(0.05, 0.75, equation, transform=plt.gca().transAxes, fontsize=12, verticalalignment='top')
plt.text(0.05, 0.80, r_squared_text, transform=plt.gca().transAxes, fontsize=12, verticalalignment='top')

plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.7)

plt.legend()

plt.show()

# %%
residuos = pd.Series(residuos)
residuos.replace([np.inf, -np.inf], np.nan, inplace=True)

residuos = residuos.dropna()

# %%
media_residuos = np.mean(residuos)

plt.scatter(range(len(residuos)), residuos, color='blue', alpha=0.7, label='Residues - Exp. Regen.')
plt.axhline(y=media_residuos, color='red', linestyle='--', label='Residues avg.')
plt.xlabel('Point index')
plt.ylabel('Residues - Exp. Regen.')
plt.title('Residue scatter plot - Exp. Regen.')
plt.legend()
plt.grid(True, alpha=0.5)
plt.show()

# %%
mean = np.mean(residuos)
std = np.std(residuos)

sns.kdeplot(residuos, fill=True, color='blue', label='Density Plot')

x_values = np.linspace(min(residuos), max(residuos), 100)

plt.plot(x_values, norm.pdf(x_values, mean, std), color='red', linestyle='dashed', label='Curva Normal')

plt.title('Density Plot dos Resíduos com Curva Normal')
plt.xlabel('Resíduos')
plt.ylabel('Densidade')

plt.legend()

plt.show()
# Out:
# C:\Users\duart\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# 150  39.820238  39.6  -0.220238
# 151  44.868819  39.6  -5.268819
# 152  30.586825  34.4   3.813175
# 153  43.305716  47.2   3.894284
# 154  52.427334  48.0  -4.427334
# 155  46.165146  49.2   3.034854
# 156  49.337915  38.4 -10.937915
# 157  50.038212  59.2   9.161788
# 158  48.778697  44.8  -3.978697
# 159  40.911723  46.0   5.088277
# 160  48.341795  47.6  -0.741795
# 161  45.197625  46.4   1.202375
# 162  42.608422  46.0   3.391578
# 163  49.885100  50.4   0.514900
# 164  51.121005  46.4  -4.721005
# 165  42.715790  50.8   8.084210
# 166  40.597771  42.0   1.402229
# 167  44.930152  54.0   9.069848
# 168  43.624018  44.8   1.175982
# 169  47.914121  49.2   1.285879
# 170  48.477237  48.0  -0.477237
# 171  36.542222  36.0  -0.542222
# 172  40.820961  36.8  -4.020961
# 173  40.586257  37.2  -3.386257
# 174  45.416523  53.2   7.783477
# 175  50.324164  44.4  -5.924164
# 176  48.076577  56.0   7.923423

# %%
# Teste de Shapiro-Wilk
shapiro_test = stats.shapiro(residuos)
print("Estatística de teste:", shapiro_test[0])
print("Valor-p:", shapiro_test[1])
# Out:
# Estatística de teste: 0.9814675450325012
# Valor-p: 0.018628690391778946

# %%
import statsmodels.api as sm
from statsmodels.stats.diagnostic import het_breuschpagan

# Suponha que você tenha ajustado um modelo de regressão e tenha os resíduos e as variáveis explicativas
# Substitua 'residuos' pelos seus resíduos e 'X' pelas suas variáveis explicativas

# Realiza o teste de Breusch-Pagan/Cook-Weisberg
lm, lm_p_value, fvalue, f_p_value = het_breuschpagan(residuos, X)

# Imprime os resultados
print("Estatística LM:", lm)
print("Valor-p LM:", lm_p_value)
print("Estatística F:", fvalue)
print("Valor-p F:", f_p_value)
# Out:
# Estatística LM: 4.234817177478919
# Valor-p LM: 0.039602888588626796
# Estatística F: 4.289596977535252
# Valor-p F: 0.03981382452659804

# %%
from scipy.stats import norm

# Calcula o teste de Durbin-Watson
durbin_watson_test = sm.stats.stattools.durbin_watson(residuos)

# Imprime o resultado
print("Estatística de Durbin-Watson:", durbin_watson_test)

nobs = len(residuos)
nvars = 1

# Calculando o valor crítico DW
d_critico = sm.stats.stattools.durbin_watson(residuos)

# Calculando DL, DU, 4-DL e 4-DU
DL = 1.521 - 1.25 * (nvars / nobs)
DU = 1.521 + 1.25 * (nvars / nobs)
quatro_DL = 4.0 - DL
quatro_DU = 4.0 - DU

# Imprimindo os resultados
print("DL:", DL)
print("DU:", DU)
print("4-DL:", quatro_DL)
print("4-DU:", quatro_DU)
# Out:
# Estatística de Durbin-Watson: 1.9609415502714997
# DL: 1.5139378531073446
# DU: 1.5280621468926552
# 4-DL: 2.4860621468926554
# 4-DU: 2.471937853107345

# %%
mape = np.mean(np.abs((y - y_pred) / y)) * 100

print(f"MAPE: {mape:.2f}%")
# Out:
# MAPE: 8.37%
