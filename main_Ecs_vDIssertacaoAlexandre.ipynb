# %%
import os
import pandas as pd
import numpy as np
import time
from glob import glob
from openpyxl import load_workbook
from ModeloMatematico1_MultiplosEc import ModeloMatematico as ModelFleetSize_MultiplosEc
from ModeloMatematico2_MultiplosEc import ModeloMatematico as ModelConsumo_MultiplosEc
from ModeloMatematico1_Fisico import ModeloMatematico as ModelFleetSize_Fisico
from ModeloMatematico2_Fisico import ModeloMatematico as ModelConsumo_Fisico

# %%
# Caminho do arquivo Excel
caminho_arquivo = f"./Resultados_Ecs.xlsx"

# Ler todas as abas
dados = []
instancias = []
resumo = []
# Mostrar os nomes das abas e seus respectivos DataFrames
atualizar = True
if atualizar:
    abas = pd.read_excel(caminho_arquivo, sheet_name=None)
    for nome_aba, df in abas.items():
        #print(f'Aba: {nome_aba}')
        #print(df.head())  # Exibe as primeiras linhas do DataFrame
        dado = df.to_dict(orient="records")
        #print(dado)
        if nome_aba != "resumo":
            dados.append(dado)
            instancias.append(nome_aba)
        else:
            resumo = dado

# %%
# Funcao
def Get_Di(Pontos, file):
    df = pd.read_excel("DELIVERIES.xlsx")
    df['data'] = pd.to_datetime(df['tour_date'])
    df['dia'] = df['data'].dt.day
    df['mes'] = df['data'].dt.month
    df['ano'] = df['data'].dt.year

    data = str(file).replace(".xlsx", "")[-10:]
    dia = int(data[-2:])
    mes = int(data[-5:-3])
    ano = int(data[:4])
    
    df_demandas = df[df['ano']==ano]
    df_demandas = df_demandas[df_demandas['mes']==mes]
    df_demandas = df_demandas[df_demandas['dia']==dia]
    dict_demanda = df_demandas.to_dict(orient="records")
    
    d_i = np.zeros(len(Pontos))

    for d in dict_demanda:
        client_id = d["client_id"]
        weight_kg = d["weight_kg"]

        if client_id not in Pontos: continue
        i = Pontos.index(client_id)
        d_i[i] = weight_kg
        
    

    return d_i

# %%
def combinacoes_2_a_2(conjunto, k=2):
    # Converte o conjunto para uma lista para facilitar o acesso por índice
    lista = list(conjunto)
    resultado = []
    
    def gerar_combinacoes(prefixo, inicio, k=2):
        # Quando o prefixo tem 2 elementos, adiciona ao resultado
        if len(prefixo) == k:
            resultado.append(tuple(prefixo))
            return
        
        # Loop para escolher os elementos
        for i in range(inicio, len(lista)):
            # Adiciona o próximo elemento ao prefixo e chama recursivamente
            gerar_combinacoes(prefixo + [lista[i]], i + 1, k)

    # Chama a função recursiva inicial
    gerar_combinacoes([], 0, k)
    return resultado

def CriarConjuntoCorteHiperplane(qntClientes):
    S = []
    __S = lambda __n: [list(s) for s in combinacoes_2_a_2(list(range(1, qntClientes+1)), __n)]
    for __n in range(2, 4):
        list_S = __S(__n)
        S += list_S
        
    return S

# %%
# Leitura de Arquivos
CONJUNTO_CORTES = dict()

INSTANCIAS = []

for file in glob("Instancias Clusters/*.xlsx"):
    try:
        df = pd.read_excel(file, "Pontos")

        def converter_id(valor):
            if valor == "CD":
                return valor  # Retorna "CD" sem alterar
            try:
                return float(valor)  # Tenta converter o valor para número
            except ValueError:
                return valor  # Se não for possível converter, retorna o valor original

        # Aplicar a função à coluna 'ID'
        df['ID'] = df['ID'].apply(converter_id)

        df_Energia = pd.read_excel(file, "Tabela Energia", usecols=['origin', 'destination', 'distancia (m)', 'e_ij_fixo', 'e_ij'])
        dict_Energia = df_Energia.to_dict(orient='records')    
        clusters = df["Cluster"].unique()

        CD = df[df["ID"]=="CD"]
        CD = list(CD["ID"].to_list())[0]
        for cluster in clusters:
            if cluster == "CD": continue
            clientes = df[df["Cluster"]==cluster]
            clientes = list(clientes["ID"].to_list())

            if len(clientes) not in CONJUNTO_CORTES:
                print("CRIANDO CORTES", len(clientes))
                print(file)
                CONJUNTO_CORTES[len(clientes)] = CriarConjuntoCorteHiperplane(len(clientes))
            
            # PONTOS
            DADO = {"file": file, "cluster": cluster, "PONTOS": [CD] + clientes}
            

            # DADOS DISTANCIA
            d_ij = np.zeros(shape=(len(DADO["PONTOS"]), len(DADO["PONTOS"])))
            e_FIXO_ij = np.zeros(shape=(len(DADO["PONTOS"]), len(DADO["PONTOS"])))
            e_ij = np.zeros(shape=(len(DADO["PONTOS"]), len(DADO["PONTOS"])))

            for d in dict_Energia:
                i = d["origin"]
                j = d["destination"]
                
                if i not in DADO["PONTOS"]: continue
                if j not in DADO["PONTOS"]: continue
                
                idx_i = DADO["PONTOS"].index(i)
                idx_j = DADO["PONTOS"].index(j)

                d_ij[idx_i, idx_j] = d["distancia (m)"]
                e_FIXO_ij[idx_i, idx_j] = d["e_ij_fixo"] 
                e_ij[idx_i, idx_j] = d["e_ij"]

            d_ij[d_ij == 0] = np.inf
            e_FIXO_ij[e_FIXO_ij == 0] = np.inf
            e_ij[e_ij == 0] = np.inf
            
            # ATENCAO TAXA DE AUMENTO DE DISTANCIA ABAIXO:
            d_ij = d_ij / 1000 * 1.2215
            DADO["d_ij"] = d_ij
            DADO["e_fixo_ij"] = e_FIXO_ij
            DADO["e_ij"] = e_ij
            
            DADO["d_i"] = Get_Di(DADO["PONTOS"], file)
            INSTANCIAS.append(DADO.copy())
    except:
        print("FALHA EM UM ARQUIVO!!!")
        print(file)
    try:
        del df, df_Energia, dict_Energia, clusters, CD, clientes, d_ij, e_FIXO_ij, e_ij, DADO
    except:
        pass
# Out:
# CRIANDO CORTES 58
# Instancias Clusters\tabelas_2023-09-06.xlsx
# CRIANDO CORTES 22
# Instancias Clusters\tabelas_2023-09-06.xlsx
# CRIANDO CORTES 48
# Instancias Clusters\tabelas_2023-09-06.xlsx
# CRIANDO CORTES 37
# Instancias Clusters\tabelas_2023-09-06.xlsx
# CRIANDO CORTES 49
# Instancias Clusters\tabelas_2023-09-06.xlsx
# CRIANDO CORTES 31
# Instancias Clusters\tabelas_2023-09-15.xlsx
# CRIANDO CORTES 40
# Instancias Clusters\tabelas_2023-09-15.xlsx
# CRIANDO CORTES 64
# Instancias Clusters\tabelas_2023-09-15.xlsx
# CRIANDO CORTES 35
# Instancias Clusters\tabelas_2023-09-15.xlsx
# CRIANDO CORTES 34
# Instancias Clusters\tabelas_2023-09-20.xlsx
# CRIANDO CORTES 84
# Instancias Clusters\tabelas_2023-09-20.xlsx
# CRIANDO CORTES 60
# Instancias Clusters\tabelas_2023-09-20.xlsx
# CRIANDO CORTES 36
# Instancias Clusters\tabelas_2023-09-20.xlsx
# CRIANDO CORTES 13
# Instancias Clusters\tabelas_2023-09-20.xlsx
# CRIANDO CORTES 53
# Instancias Clusters\tabelas_2023-09-22.xlsx
# CRIANDO CORTES 50
# Instancias Clusters\tabelas_2023-09-22.xlsx
# CRIANDO CORTES 30
# Instancias Clusters\tabelas_2023-09-22.xlsx
# CRIANDO CORTES 33
# Instancias Clusters\tabelas_2023-10-11.xlsx
# CRIANDO CORTES 72
# Instancias Clusters\tabelas_2023-10-11.xlsx
# CRIANDO CORTES 55
# Instancias Clusters\tabelas_2023-10-11.xlsx
# CRIANDO CORTES 20
# Instancias Clusters\tabelas_2023-10-11.xlsx
# CRIANDO CORTES 17
# Instancias Clusters\tabelas_2023-10-17.xlsx
# CRIANDO CORTES 65
# Instancias Clusters\tabelas_2023-10-17.xlsx
# CRIANDO CORTES 42
# Instancias Clusters\tabelas_2023-10-17.xlsx
# CRIANDO CORTES 28
# Instancias Clusters\tabelas_2023-10-20.xlsx
# CRIANDO CORTES 79
# Instancias Clusters\tabelas_2023-10-21.xlsx
# CRIANDO CORTES 38
# Instancias Clusters\tabelas_2023-10-21.xlsx
# CRIANDO CORTES 39
# Instancias Clusters\tabelas_2023-10-26.xlsx
# CRIANDO CORTES 29
# Instancias Clusters\tabelas_2023-10-26.xlsx
# CRIANDO CORTES 82
# Instancias Clusters\tabelas_2023-11-01.xlsx
# CRIANDO CORTES 26
# Instancias Clusters\tabelas_2023-11-01.xlsx
# CRIANDO CORTES 59
# Instancias Clusters\tabelas_2023-11-04.xlsx
# CRIANDO CORTES 27
# Instancias Clusters\tabelas_2023-11-04.xlsx
# CRIANDO CORTES 67
# Instancias Clusters\tabelas_2023-11-07.xlsx
# CRIANDO CORTES 73
# Instancias Clusters\tabelas_2023-11-07.xlsx
# CRIANDO CORTES 8
# Instancias Clusters\tabelas_2023-11-07.xlsx
# CRIANDO CORTES 62
# Instancias Clusters\tabelas_2023-11-14.xlsx
# CRIANDO CORTES 44
# Instancias Clusters\tabelas_2023-11-14.xlsx
# CRIANDO CORTES 24
# Instancias Clusters\tabelas_2023-11-17.xlsx
# CRIANDO CORTES 66
# Instancias Clusters\tabelas_2023-11-17.xlsx
# CRIANDO CORTES 52
# Instancias Clusters\tabelas_2023-11-17.xlsx
# CRIANDO CORTES 19
# Instancias Clusters\tabelas_2023-11-22.xlsx
# CRIANDO CORTES 71
# Instancias Clusters\tabelas_2023-11-24.xlsx
# CRIANDO CORTES 21
# Instancias Clusters\tabelas_2023-11-24.xlsx
# CRIANDO CORTES 51
# Instancias Clusters\tabelas_2023-11-25.xlsx
# CRIANDO CORTES 23
# Instancias Clusters\tabelas_2023-11-25.xlsx
# CRIANDO CORTES 18
# Instancias Clusters\tabelas_2023-11-28.xlsx
# CRIANDO CORTES 87
# Instancias Clusters\tabelas_2023-11-29.xlsx
# CRIANDO CORTES 25
# Instancias Clusters\tabelas_2023-11-29.xlsx
# CRIANDO CORTES 41
# Instancias Clusters\tabelas_2023-11-30.xlsx
# CRIANDO CORTES 43
# Instancias Clusters\tabelas_2023-11-30.xlsx
# CRIANDO CORTES 47
# Instancias Clusters\tabelas_2023-11-30.xlsx
# CRIANDO CORTES 46
# Instancias Clusters\tabelas_2023-12-01.xlsx
# CRIANDO CORTES 54
# Instancias Clusters\tabelas_2023-12-01.xlsx
# CRIANDO CORTES 32
# Instancias Clusters\tabelas_2023-12-02.xlsx
# CRIANDO CORTES 63
# Instancias Clusters\tabelas_2023-12-02.xlsx
# CRIANDO CORTES 85
# Instancias Clusters\tabelas_2023-12-06.xlsx
# CRIANDO CORTES 68
# Instancias Clusters\tabelas_2023-12-06.xlsx
# CRIANDO CORTES 12
# Instancias Clusters\tabelas_2023-12-06.xlsx
# CRIANDO CORTES 93
# Instancias Clusters\tabelas_2023-12-11.xlsx
# CRIANDO CORTES 69
# Instancias Clusters\tabelas_2023-12-12.xlsx
# CRIANDO CORTES 57
# Instancias Clusters\tabelas_2024-01-05.xlsx
# CRIANDO CORTES 45
# Instancias Clusters\tabelas_2024-01-06.xlsx
# CRIANDO CORTES 78
# Instancias Clusters\tabelas_2024-01-09.xlsx
# CRIANDO CORTES 83
# Instancias Clusters\tabelas_2024-02-20.xlsx

# %%
def vrp_vizinho_mais_proximo(pontos, num_veiculos, distancia, d_i):
    rotas = [[] for _ in range(num_veiculos)]  # Listas de rotas para cada veículo
    num_clientes = len(pontos)
    d_i = np.array(d_i)

    # Adiciona o ponto de partida (depósito) como o primeiro ponto
    deposito = pontos[0]
    clientes = pontos[1:].copy()  # Clientes são todos os pontos exceto o depósito
    
    for i in range(num_veiculos):
        rota = [deposito]  # Começa no depósito
        distancia_total = 0
        
        while clientes:
            ultimo_ponto = pontos[rota[-1]]
            # Encontra o cliente mais próximo
            
            proximo_cliente = min(clientes, key=lambda c: distancia[ultimo_ponto, c])
            #print(proximo_cliente)
            if distancia[ultimo_ponto, proximo_cliente] == np.inf:
                break
            elif d_i[rota+[proximo_cliente]].sum() > 7890:
                distancia[ultimo_ponto, proximo_cliente] = np.inf
            else:
                distancia_total += distancia[ultimo_ponto, proximo_cliente]
                clientes.remove(proximo_cliente)
                # Adiciona o índice do cliente na rota
                rota.append(pontos.index(proximo_cliente))

        rota.append(deposito)  # Retorna ao depósito
        rotas[i] = rota

    return rotas

# %%
def substituir_inf_nan(instancia):
    for key in ['d_ij', 'e_fixo_ij', 'e_ij', 'd_i']:
        if key in instancia:
            instancia[key] = np.nan_to_num(instancia[key], nan=1000, posinf=1000, neginf=1000)
    return instancia

INSTANCIAS = [substituir_inf_nan(instancia) for instancia in INSTANCIAS]

# %%
from copy import copy
rotas_iniciais = []
for idx, instancia in enumerate(INSTANCIAS):
    Pontos = instancia["PONTOS"]
    d_i = instancia["d_i"]
    d_ij = instancia["d_ij"]

    N = list(range(len(Pontos))) # 1 CD e 10 CLientes

    Q = 7920 # CAPACIDADE LIQUIDA DO VEICULO (KG)

    rotas = vrp_vizinho_mais_proximo(N, 20, copy(d_ij), d_i)
    #print(rotas)

    # VALIDAR ROTAS:
    
    d_i = np.array(d_i)
    rotas_dict = {"x_ijk": dict(), "f_ijk": dict(), "g_ijk": dict()}
    k = 0
    for rota in rotas:
        if len(rota)==2: continue
        #print(d_i[rota])
        if d_i[rota].sum() > Q:
            print("INVALIDO CARGA")
        bateria = 105
        for i_j in range(1, len(rota)):
            i = rota[i_j-1]
            j = rota[i_j]
            if i == 0:
                bateria -= d_ij[0, j] * 0.74
            elif j == 0:
                bateria -= d_ij[i, 0] * 0.57
            else:
                bateria -= d_ij[i, j] * 1.0

            rotas_dict["x_ijk"][(i,j,k)] = 1    
        if bateria < 20:
            print("INVALIDO BATERIA")
            print(idx)

        k+=1
    #print(rotas_dict)

    rotas_iniciais.append(rotas_dict)
# Out:
# INVALIDO BATERIA
# 83

# %%
len(rotas_iniciais)
# Out:
# 174

# %%
INSTANCIAS[130]['cluster']
# Out:
# 4

# %%
# Verifique se o arquivo existe e carregue-o
if os.path.exists("./Resultados_Ecs.xlsx"):
    existing_data = pd.read_excel("./Resultados_Ecs.xlsx", sheet_name=None)
    existing_summary = existing_data.get('resumo', pd.DataFrame())
else:
    existing_summary = pd.DataFrame()

# Listar combinações de file e cluster já processadas
processed_combinations = [
    (file, cluster) for file, cluster in zip(existing_summary["File"], existing_summary["cluster"])
] if not existing_summary.empty else []

# %%
len(processed_combinations)
# Out:
# 173

# %%
file_path = "./Resultados_Ecs.xlsx"

# %%
# PROCEDIMENTO:

import logging
import os
import traceback

log_filename = "Instancias_Ecs.log"

# Configuração básica do logger
logging.basicConfig(
    filename=log_filename,
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s",
)

dados = []
resumo = []

for idx, inst in enumerate(INSTANCIAS, start=0):

    inst_key = (inst["file"], inst["cluster"])
    print("INSTANCIA:", inst_key)
    print("INDEX:", idx)

    # Verificar se a combinação file + cluster já foi processada
    if inst_key in processed_combinations:
        print(f"Instância {inst['file']} - Cluster {inst['cluster']} já processada. Pulando...")
        print()
        continue

    # MODELO MULTIPLOS PARAMETROS MACROSCOPICOS
    # TAMANHO DE FROTA OTIMO:
    C = range(1, len(inst["PONTOS"]))
    N = range(0, len(inst["PONTOS"]))
    A = [(i, j) for i in N for j in N if i != j]
    K = range(9)
    Q = 7920
    d_i = inst["d_i"]
    d_ij = inst["d_ij"]
    SOH = 0.95
    Bmax = 105
    Bmin = 20
    Error = 2.42

    rotainicial = rotas_iniciais[idx]

    S = CONJUNTO_CORTES[len(C)]

    t_total = time.time()

    try:
        # ETAPA 1
        _m, x_ijk, f_ijk, g_ijk, gap, FleetSize = ModelFleetSize_MultiplosEc(C, N, A, K, Q, d_i, d_ij, SOH, Bmax, Bmin, Error, rotainicial, S)
        FleetSize = int(FleetSize)
        print(FleetSize)

        # ETAPA 2
        tempo_opt = time.time()

        _rotainicial = {"x_ijk": dict(), "f_ijk": dict(), "g_ijk": dict()}
        K_disp = []
        for i, j in A:
            for k in K:
                if x_ijk[i, j, k].X > 0.1:
                    _rotainicial["x_ijk"][(i, j, k)] = 1
                    if k not in K_disp:
                        K_disp.append(k)

        rotainicial = {"x_ijk": dict(), "f_ijk": dict(), "g_ijk": dict()}

        for i, j, k in _rotainicial["x_ijk"]:
            if _rotainicial["x_ijk"][(i, j, k)] == 1:
                rotainicial["x_ijk"][(i, j, K_disp.index(k))] = 1

        del _rotainicial

        K = range(FleetSize)
        _m, x_ijk, f_ijk, g_ijk, gap = ModelConsumo_MultiplosEc(C, N, A, K, Q, d_i, d_ij, SOH, Bmax, Bmin, Error, FleetSize, rotainicial, S)

        # PROCESSAR DADOS
        resp = {k: [] for k in K}
        dados.append([])

        dist = 0

        consumo = _m.objVal

        lotacao_k = []
        tam_frota = 0
        for k in K:
            for j in C:
                if x_ijk[0, j, k].X > 0.1:
                    tam_frota += 1
                    lotacao_k.append(f_ijk[0, j, k].X)

        consumos_k = []
        distancias_k = []

        for k in K:
            somatorio_consumo = 0
            somatorio_distancia = 0
            for i, j in A:
                x_ijk_value = x_ijk[i, j, k].X
                f_ijk_value = f_ijk[i, j, k].X
                d_ij_value = d_ij[i, j]

                if i == 0:
                    somatorio_consumo += x_ijk_value * d_ij_value * 0.738
                elif j == 0:
                    somatorio_consumo += x_ijk_value * d_ij_value * 0.570
                else:
                    somatorio_consumo += x_ijk_value * d_ij_value * 1.005

                somatorio_distancia += x_ijk_value * d_ij_value

            consumos_k.append(somatorio_consumo)
            distancias_k.append(somatorio_distancia)

        for k in K:
            for i, j in A:
                if x_ijk[i, j, k].X > 0.1:
                    resp[k].append((i, j))
                    dados[-1].append({"variavel": "x_ijk", "i": i, "j": j, "k": k, "value": x_ijk[i, j, k].X, "obs": ""})
                    dados[-1].append({"variavel": "f_ijk", "i": i, "j": j, "k": k, "value": f_ijk[i, j, k].X, "obs": ""})
                    dados[-1].append({"variavel": "g_ijk", "i": i, "j": j, "k": k, "value": g_ijk[i, j, k].X, "obs": ""})
                    dist += d_ij[i, j] * x_ijk[i, j, k].X
                else:
                    if f_ijk[i, j, k].X > 0.1 or g_ijk[i, j, k].X > 0.1:
                        dados[-1].append({"variavel": "x_ijk", "i": i, "j": j, "k": k, "value": x_ijk[i, j, k].X, "obs": "Sim"})
                        dados[-1].append({"variavel": "f_ijk", "i": i, "j": j, "k": k, "value": f_ijk[i, j, k].X, "obs": "Sim"})
                        dados[-1].append({"variavel": "g_ijk", "i": i, "j": j, "k": k, "value": g_ijk[i, j, k].X, "obs": "Sim"})

        resumo.append({"File": inst["file"], "cluster": inst["cluster"], "lotacao_k": lotacao_k, "dist": dist, "dist_k": [float(d) for d in distancias_k],"consumo": consumo*1.2215, "consumo_k": [float(c) for c in consumos_k], "FleetSize": tam_frota, "t_total": time.time() - t_total, "tempo Opt": time.time() - tempo_opt, "tempo fleet": tempo_opt - t_total, "gap": gap})
        t = time.time()
        
        for k in K:
            if not len(resp[k]): continue
            print(resp[k])

        del _m
        del x_ijk
        del f_ijk
        del g_ijk
        del gap

        tam_frota = 0

        if os.path.exists(file_path):
            wb = load_workbook(file_path)
            if "resumo" in wb.sheetnames:
                existing_summary = pd.read_excel(file_path, sheet_name="resumo")
            else:
                existing_summary = pd.DataFrame()
        else:
            existing_summary = pd.DataFrame()

        new_summary_df = pd.DataFrame([resumo[-1]])

        if not existing_summary.empty:
            is_duplicate = (
                (existing_summary["File"] == resumo[-1]["File"]) &
                (existing_summary["cluster"] == resumo[-1]["cluster"])
            ).any()
        else:
            is_duplicate = False

        if not is_duplicate:
            existing_summary = pd.concat([existing_summary, new_summary_df], ignore_index=True)

        with pd.ExcelWriter(file_path, engine='openpyxl', mode='a', if_sheet_exists='replace') as writer:
            existing_summary.to_excel(writer, sheet_name="resumo", index=False)

            df = pd.DataFrame(dados[-1])

            sheet_name = f'Instancia_{idx + 1}'

            df.to_excel(writer, sheet_name=sheet_name, index=False)

    except Exception as e:
        # Informações básicas
        print(f"-----------------ERRO NA INSTÂNCIA {inst['file']}-----------------")
        print(f"Detalhes do erro: {str(e)}")
        
        # Tipo da exceção
        exc_type = type(e).__name__
        print(f"Tipo do erro: {exc_type}")
        
        # Traceback completo no console
        traceback.print_exc()

        # Log do erro
        logging.error(f"ERRO NA INSTÂNCIA {inst['file']} - {str(e)}")
        logging.error(f"Tipo do erro: {exc_type}")
        logging.error(traceback.format_exc())

        # Registrar variáveis intermediárias relevantes
        logging.error(f"Estado da variável 'inst': {inst}")
        logging.error(f"Últimos dados processados: {locals()}")  # Exibe todas as variáveis locais
        pass
# Out:
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-09-06.xlsx', 5)
# INDEX: 0
# Instância Instancias Clusters\tabelas_2023-09-06.xlsx - Cluster 5 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-09-06.xlsx', 1)
# INDEX: 1
# Instância Instancias Clusters\tabelas_2023-09-06.xlsx - Cluster 1 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-09-06.xlsx', 2)
# INDEX: 2
# Instância Instancias Clusters\tabelas_2023-09-06.xlsx - Cluster 2 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-09-06.xlsx', 3)
# INDEX: 3
# Instância Instancias Clusters\tabelas_2023-09-06.xlsx - Cluster 3 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-09-06.xlsx', 4)
# INDEX: 4
# Instância Instancias Clusters\tabelas_2023-09-06.xlsx - Cluster 4 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-09-15.xlsx', 4)
# INDEX: 5
# Instância Instancias Clusters\tabelas_2023-09-15.xlsx - Cluster 4 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-09-15.xlsx', 2)
# INDEX: 6
# Instância Instancias Clusters\tabelas_2023-09-15.xlsx - Cluster 2 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-09-15.xlsx', 1)
# INDEX: 7
# Instância Instancias Clusters\tabelas_2023-09-15.xlsx - Cluster 1 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-09-15.xlsx', 3)
# INDEX: 8
# Instância Instancias Clusters\tabelas_2023-09-15.xlsx - Cluster 3 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-09-15.xlsx', 5)
# INDEX: 9
# Instância Instancias Clusters\tabelas_2023-09-15.xlsx - Cluster 5 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-09-20.xlsx', 1)
# INDEX: 10
# Instância Instancias Clusters\tabelas_2023-09-20.xlsx - Cluster 1 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-09-20.xlsx', 3)
# INDEX: 11
# Instância Instancias Clusters\tabelas_2023-09-20.xlsx - Cluster 3 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-09-20.xlsx', 4)
# INDEX: 12
# Instância Instancias Clusters\tabelas_2023-09-20.xlsx - Cluster 4 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-09-20.xlsx', 2)
# INDEX: 13
# Instância Instancias Clusters\tabelas_2023-09-20.xlsx - Cluster 2 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-09-20.xlsx', 5)
# INDEX: 14
# Instância Instancias Clusters\tabelas_2023-09-20.xlsx - Cluster 5 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-09-22.xlsx', 3)
# INDEX: 15
# Instância Instancias Clusters\tabelas_2023-09-22.xlsx - Cluster 3 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-09-22.xlsx', 1)
# INDEX: 16
# Instância Instancias Clusters\tabelas_2023-09-22.xlsx - Cluster 1 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-09-22.xlsx', 4)
# INDEX: 17
# Instância Instancias Clusters\tabelas_2023-09-22.xlsx - Cluster 4 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-09-22.xlsx', 5)
# INDEX: 18
# Instância Instancias Clusters\tabelas_2023-09-22.xlsx - Cluster 5 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-09-22.xlsx', 2)
# INDEX: 19
# Instância Instancias Clusters\tabelas_2023-09-22.xlsx - Cluster 2 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-10-11.xlsx', 5)
# INDEX: 20
# Instância Instancias Clusters\tabelas_2023-10-11.xlsx - Cluster 5 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-10-11.xlsx', 1)
# INDEX: 21
# Instância Instancias Clusters\tabelas_2023-10-11.xlsx - Cluster 1 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-10-11.xlsx', 2)
# INDEX: 22
# Instância Instancias Clusters\tabelas_2023-10-11.xlsx - Cluster 2 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-10-11.xlsx', 3)
# INDEX: 23
# Instância Instancias Clusters\tabelas_2023-10-11.xlsx - Cluster 3 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-10-11.xlsx', 4)
# INDEX: 24
# Instância Instancias Clusters\tabelas_2023-10-11.xlsx - Cluster 4 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-10-17.xlsx', 4)
# INDEX: 25
# Instância Instancias Clusters\tabelas_2023-10-17.xlsx - Cluster 4 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-10-17.xlsx', 5)
# INDEX: 26
# Instância Instancias Clusters\tabelas_2023-10-17.xlsx - Cluster 5 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-10-17.xlsx', 1)
# INDEX: 27
# Instância Instancias Clusters\tabelas_2023-10-17.xlsx - Cluster 1 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-10-17.xlsx', 2)
# INDEX: 28
# Instância Instancias Clusters\tabelas_2023-10-17.xlsx - Cluster 2 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-10-17.xlsx', 3)
# INDEX: 29
# Instância Instancias Clusters\tabelas_2023-10-17.xlsx - Cluster 3 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-10-20.xlsx', 4)
# INDEX: 30
# Instância Instancias Clusters\tabelas_2023-10-20.xlsx - Cluster 4 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-10-20.xlsx', 3)
# INDEX: 31
# Instância Instancias Clusters\tabelas_2023-10-20.xlsx - Cluster 3 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-10-20.xlsx', 1)
# INDEX: 32
# Instância Instancias Clusters\tabelas_2023-10-20.xlsx - Cluster 1 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-10-20.xlsx', 5)
# INDEX: 33
# Instância Instancias Clusters\tabelas_2023-10-20.xlsx - Cluster 5 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-10-20.xlsx', 2)
# INDEX: 34
# Instância Instancias Clusters\tabelas_2023-10-20.xlsx - Cluster 2 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-10-21.xlsx', 4)
# INDEX: 35
# Instância Instancias Clusters\tabelas_2023-10-21.xlsx - Cluster 4 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-10-21.xlsx', 2)
# INDEX: 36
# Instância Instancias Clusters\tabelas_2023-10-21.xlsx - Cluster 2 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-10-21.xlsx', 5)
# INDEX: 37
# Instância Instancias Clusters\tabelas_2023-10-21.xlsx - Cluster 5 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-10-21.xlsx', 1)
# INDEX: 38
# Instância Instancias Clusters\tabelas_2023-10-21.xlsx - Cluster 1 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-10-21.xlsx', 3)
# INDEX: 39
# Instância Instancias Clusters\tabelas_2023-10-21.xlsx - Cluster 3 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-10-26.xlsx', 2)
# INDEX: 40
# Instância Instancias Clusters\tabelas_2023-10-26.xlsx - Cluster 2 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-10-26.xlsx', 3)
# INDEX: 41
# Instância Instancias Clusters\tabelas_2023-10-26.xlsx - Cluster 3 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-10-26.xlsx', 4)
# INDEX: 42
# Instância Instancias Clusters\tabelas_2023-10-26.xlsx - Cluster 4 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-10-26.xlsx', 6)
# INDEX: 43
# Instância Instancias Clusters\tabelas_2023-10-26.xlsx - Cluster 6 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-10-26.xlsx', 1)
# INDEX: 44
# Instância Instancias Clusters\tabelas_2023-10-26.xlsx - Cluster 1 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-10-26.xlsx', 5)
# INDEX: 45
# Instância Instancias Clusters\tabelas_2023-10-26.xlsx - Cluster 5 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-01.xlsx', 4)
# INDEX: 46
# Instância Instancias Clusters\tabelas_2023-11-01.xlsx - Cluster 4 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-01.xlsx', 1)
# INDEX: 47
# Instância Instancias Clusters\tabelas_2023-11-01.xlsx - Cluster 1 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-01.xlsx', 2)
# INDEX: 48
# Instância Instancias Clusters\tabelas_2023-11-01.xlsx - Cluster 2 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-01.xlsx', 3)
# INDEX: 49
# Instância Instancias Clusters\tabelas_2023-11-01.xlsx - Cluster 3 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-01.xlsx', 5)
# INDEX: 50
# Instância Instancias Clusters\tabelas_2023-11-01.xlsx - Cluster 5 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-04.xlsx', 2)
# INDEX: 51
# Instância Instancias Clusters\tabelas_2023-11-04.xlsx - Cluster 2 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-04.xlsx', 3)
# INDEX: 52
# Instância Instancias Clusters\tabelas_2023-11-04.xlsx - Cluster 3 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-04.xlsx', 4)
# INDEX: 53
# Instância Instancias Clusters\tabelas_2023-11-04.xlsx - Cluster 4 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-04.xlsx', 1)
# INDEX: 54
# Instância Instancias Clusters\tabelas_2023-11-04.xlsx - Cluster 1 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-04.xlsx', 5)
# INDEX: 55
# Instância Instancias Clusters\tabelas_2023-11-04.xlsx - Cluster 5 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-07.xlsx', 4)
# INDEX: 56
# Instância Instancias Clusters\tabelas_2023-11-07.xlsx - Cluster 4 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-07.xlsx', 1)
# INDEX: 57
# Instância Instancias Clusters\tabelas_2023-11-07.xlsx - Cluster 1 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-07.xlsx', 3)
# INDEX: 58
# Instância Instancias Clusters\tabelas_2023-11-07.xlsx - Cluster 3 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-07.xlsx', 5)
# INDEX: 59
# Instância Instancias Clusters\tabelas_2023-11-07.xlsx - Cluster 5 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-07.xlsx', 2)
# INDEX: 60
# Instância Instancias Clusters\tabelas_2023-11-07.xlsx - Cluster 2 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-14.xlsx', 1)
# INDEX: 61
# Instância Instancias Clusters\tabelas_2023-11-14.xlsx - Cluster 1 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-14.xlsx', 2)
# INDEX: 62
# Instância Instancias Clusters\tabelas_2023-11-14.xlsx - Cluster 2 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-14.xlsx', 3)
# INDEX: 63
# Instância Instancias Clusters\tabelas_2023-11-14.xlsx - Cluster 3 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-14.xlsx', 5)
# INDEX: 64
# Instância Instancias Clusters\tabelas_2023-11-14.xlsx - Cluster 5 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-14.xlsx', 4)
# INDEX: 65
# Instância Instancias Clusters\tabelas_2023-11-14.xlsx - Cluster 4 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-14.xlsx', 6)
# INDEX: 66
# Instância Instancias Clusters\tabelas_2023-11-14.xlsx - Cluster 6 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-17.xlsx', 3)
# INDEX: 67
# Instância Instancias Clusters\tabelas_2023-11-17.xlsx - Cluster 3 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-17.xlsx', 1)
# INDEX: 68
# Instância Instancias Clusters\tabelas_2023-11-17.xlsx - Cluster 1 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-17.xlsx', 5)
# INDEX: 69
# Instância Instancias Clusters\tabelas_2023-11-17.xlsx - Cluster 5 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-17.xlsx', 2)
# INDEX: 70
# Instância Instancias Clusters\tabelas_2023-11-17.xlsx - Cluster 2 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-17.xlsx', 4)
# INDEX: 71
# Instância Instancias Clusters\tabelas_2023-11-17.xlsx - Cluster 4 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-22.xlsx', 5)
# INDEX: 72
# Instância Instancias Clusters\tabelas_2023-11-22.xlsx - Cluster 5 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-22.xlsx', 2)
# INDEX: 73
# Instância Instancias Clusters\tabelas_2023-11-22.xlsx - Cluster 2 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-22.xlsx', 1)
# INDEX: 74
# Instância Instancias Clusters\tabelas_2023-11-22.xlsx - Cluster 1 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-22.xlsx', 3)
# INDEX: 75
# Instância Instancias Clusters\tabelas_2023-11-22.xlsx - Cluster 3 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-22.xlsx', 4)
# INDEX: 76
# Instância Instancias Clusters\tabelas_2023-11-22.xlsx - Cluster 4 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-24.xlsx', 4)
# INDEX: 77
# Instância Instancias Clusters\tabelas_2023-11-24.xlsx - Cluster 4 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-24.xlsx', 1)
# INDEX: 78
# Instância Instancias Clusters\tabelas_2023-11-24.xlsx - Cluster 1 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-24.xlsx', 5)
# INDEX: 79
# Instância Instancias Clusters\tabelas_2023-11-24.xlsx - Cluster 5 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-24.xlsx', 3)
# INDEX: 80
# Instância Instancias Clusters\tabelas_2023-11-24.xlsx - Cluster 3 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-24.xlsx', 2)
# INDEX: 81
# Instância Instancias Clusters\tabelas_2023-11-24.xlsx - Cluster 2 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-25.xlsx', 2)
# INDEX: 82
# Instância Instancias Clusters\tabelas_2023-11-25.xlsx - Cluster 2 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-25.xlsx', 3)
# INDEX: 83
# Instância Instancias Clusters\tabelas_2023-11-25.xlsx - Cluster 3 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-25.xlsx', 1)
# INDEX: 84
# Instância Instancias Clusters\tabelas_2023-11-25.xlsx - Cluster 1 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-25.xlsx', 5)
# INDEX: 85
# Instância Instancias Clusters\tabelas_2023-11-25.xlsx - Cluster 5 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-25.xlsx', 6)
# INDEX: 86
# Instância Instancias Clusters\tabelas_2023-11-25.xlsx - Cluster 6 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-25.xlsx', 4)
# INDEX: 87
# Instância Instancias Clusters\tabelas_2023-11-25.xlsx - Cluster 4 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-28.xlsx', 1)
# INDEX: 88
# Instância Instancias Clusters\tabelas_2023-11-28.xlsx - Cluster 1 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-28.xlsx', 3)
# INDEX: 89
# Instância Instancias Clusters\tabelas_2023-11-28.xlsx - Cluster 3 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-28.xlsx', 5)
# INDEX: 90
# Instância Instancias Clusters\tabelas_2023-11-28.xlsx - Cluster 5 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-28.xlsx', 4)
# INDEX: 91
# Instância Instancias Clusters\tabelas_2023-11-28.xlsx - Cluster 4 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-28.xlsx', 2)
# INDEX: 92
# Instância Instancias Clusters\tabelas_2023-11-28.xlsx - Cluster 2 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-28.xlsx', 6)
# INDEX: 93
# Instância Instancias Clusters\tabelas_2023-11-28.xlsx - Cluster 6 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-29.xlsx', 1)
# INDEX: 94
# Instância Instancias Clusters\tabelas_2023-11-29.xlsx - Cluster 1 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-29.xlsx', 4)
# INDEX: 95
# Instância Instancias Clusters\tabelas_2023-11-29.xlsx - Cluster 4 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-29.xlsx', 2)
# INDEX: 96
# Instância Instancias Clusters\tabelas_2023-11-29.xlsx - Cluster 2 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-29.xlsx', 5)
# INDEX: 97
# Instância Instancias Clusters\tabelas_2023-11-29.xlsx - Cluster 5 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-29.xlsx', 3)
# INDEX: 98
# Instância Instancias Clusters\tabelas_2023-11-29.xlsx - Cluster 3 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-30.xlsx', 1)
# INDEX: 99
# Instância Instancias Clusters\tabelas_2023-11-30.xlsx - Cluster 1 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-30.xlsx', 5)
# INDEX: 100
# Instância Instancias Clusters\tabelas_2023-11-30.xlsx - Cluster 5 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-30.xlsx', 4)
# INDEX: 101
# Instância Instancias Clusters\tabelas_2023-11-30.xlsx - Cluster 4 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-30.xlsx', 6)
# INDEX: 102
# Instância Instancias Clusters\tabelas_2023-11-30.xlsx - Cluster 6 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-30.xlsx', 3)
# INDEX: 103
# Instância Instancias Clusters\tabelas_2023-11-30.xlsx - Cluster 3 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-11-30.xlsx', 2)
# INDEX: 104
# Instância Instancias Clusters\tabelas_2023-11-30.xlsx - Cluster 2 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-12-01.xlsx', 3)
# INDEX: 105
# Instância Instancias Clusters\tabelas_2023-12-01.xlsx - Cluster 3 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-12-01.xlsx', 4)
# INDEX: 106
# Instância Instancias Clusters\tabelas_2023-12-01.xlsx - Cluster 4 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-12-01.xlsx', 1)
# INDEX: 107
# Instância Instancias Clusters\tabelas_2023-12-01.xlsx - Cluster 1 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-12-01.xlsx', 2)
# INDEX: 108
# Instância Instancias Clusters\tabelas_2023-12-01.xlsx - Cluster 2 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-12-01.xlsx', 5)
# INDEX: 109
# Instância Instancias Clusters\tabelas_2023-12-01.xlsx - Cluster 5 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-12-01.xlsx', 6)
# INDEX: 110
# Instância Instancias Clusters\tabelas_2023-12-01.xlsx - Cluster 6 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-12-02.xlsx', 3)
# INDEX: 111
# Instância Instancias Clusters\tabelas_2023-12-02.xlsx - Cluster 3 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-12-02.xlsx', 5)
# INDEX: 112
# Instância Instancias Clusters\tabelas_2023-12-02.xlsx - Cluster 5 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-12-02.xlsx', 1)
# INDEX: 113
# Instância Instancias Clusters\tabelas_2023-12-02.xlsx - Cluster 1 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-12-02.xlsx', 2)
# INDEX: 114
# Instância Instancias Clusters\tabelas_2023-12-02.xlsx - Cluster 2 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-12-02.xlsx', 4)
# INDEX: 115
# Instância Instancias Clusters\tabelas_2023-12-02.xlsx - Cluster 4 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-12-06.xlsx', 6)
# INDEX: 116
# Instância Instancias Clusters\tabelas_2023-12-06.xlsx - Cluster 6 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-12-06.xlsx', 1)
# INDEX: 117
# Instância Instancias Clusters\tabelas_2023-12-06.xlsx - Cluster 1 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-12-06.xlsx', 5)
# INDEX: 118
# Instância Instancias Clusters\tabelas_2023-12-06.xlsx - Cluster 5 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-12-06.xlsx', 2)
# INDEX: 119
# Instância Instancias Clusters\tabelas_2023-12-06.xlsx - Cluster 2 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-12-06.xlsx', 4)
# INDEX: 120
# Instância Instancias Clusters\tabelas_2023-12-06.xlsx - Cluster 4 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-12-06.xlsx', 3)
# INDEX: 121
# Instância Instancias Clusters\tabelas_2023-12-06.xlsx - Cluster 3 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-12-08.xlsx', 6)
# INDEX: 122
# Instância Instancias Clusters\tabelas_2023-12-08.xlsx - Cluster 6 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-12-08.xlsx', 3)
# INDEX: 123
# Instância Instancias Clusters\tabelas_2023-12-08.xlsx - Cluster 3 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-12-08.xlsx', 2)
# INDEX: 124
# Instância Instancias Clusters\tabelas_2023-12-08.xlsx - Cluster 2 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-12-08.xlsx', 1)
# INDEX: 125
# Instância Instancias Clusters\tabelas_2023-12-08.xlsx - Cluster 1 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-12-08.xlsx', 4)
# INDEX: 126
# Instância Instancias Clusters\tabelas_2023-12-08.xlsx - Cluster 4 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-12-08.xlsx', 5)
# INDEX: 127
# Instância Instancias Clusters\tabelas_2023-12-08.xlsx - Cluster 5 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-12-11.xlsx', 1)
# INDEX: 128
# Instância Instancias Clusters\tabelas_2023-12-11.xlsx - Cluster 1 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-12-11.xlsx', 2)
# INDEX: 129
# Instância Instancias Clusters\tabelas_2023-12-11.xlsx - Cluster 2 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-12-11.xlsx', 4)
# INDEX: 130
# Instância Instancias Clusters\tabelas_2023-12-11.xlsx - Cluster 4 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-12-11.xlsx', 5)
# INDEX: 131
# Instância Instancias Clusters\tabelas_2023-12-11.xlsx - Cluster 5 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-12-11.xlsx', 3)
# INDEX: 132
# Instância Instancias Clusters\tabelas_2023-12-11.xlsx - Cluster 3 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-12-12.xlsx', 4)
# INDEX: 133
# Set parameter MIPGap to value 0.05
# Set parameter TimeLimit to value 300
# RESTRICOES DE CORTE DE HIPERPLANO
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i5-1235U, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 12 logical processors, using up to 12 threads
#
# Non-default parameters:
# TimeLimit  300
# MIPGap  0.05
#
# Optimize a model with 144320 rows, 132300 columns and 3393144 nonzeros
# Model fingerprint: 0xbb7e226d
# Variable types: 88200 continuous, 44100 integer (44100 binary)
# Coefficient statistics:
#   Matrix range     [9e-04, 8e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+03]
#
# Warning: Completing partial solution with 44022 unfixed non-continuous variables out of 44100
# User MIP start produced solution with objective 9 (0.50s)
# Loaded user MIP start with objective 9
#
# Presolve removed 1255 rows and 2517 columns (presolve time = 5s)...
# Presolve removed 1246 rows and 2508 columns
# Presolve time: 5.14s
# Presolved: 143074 rows, 129792 columns, 3389286 nonzeros
# Variable types: 86315 continuous, 43477 integer (43477 binary)
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root barrier log...
#
#
# Barrier performed 0 iterations in 7.88 seconds (12.79 work units)
# Barrier solve interrupted - model solved by another algorithm
#
# Concurrent spin time: 0.11s (can be avoided by choosing Method=3)
#
# Solved with dual simplex
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root barrier log...
#
#
# Barrier performed 0 iterations in 8.65 seconds (13.00 work units)
# Barrier solve interrupted - model solved by another algorithm
#
# Concurrent spin time: 0.35s (can be avoided by choosing Method=3)
#
# Solved with dual simplex
#
# Root relaxation: cutoff, 1202 iterations, 2.24 seconds (2.36 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         9.00000    9.00000  0.00%     -    8s
#
# Explored 1 nodes (1202 simplex iterations) in 8.77 seconds (13.00 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 9
#
# Optimal solution found (tolerance 5.00e-02)
# Best objective 9.000000000000e+00, best bound 9.000000000000e+00, gap 0.0000%
# 9
# Set parameter MIPGap to value 0.05
# Set parameter TimeLimit to value 7200
# RESTRICOES DE CORTE DE HIPERPLANO
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i5-1235U, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 12 logical processors, using up to 12 threads
#
# Non-default parameters:
# TimeLimit  7200
# MIPGap  0.05
#
# Optimize a model with 144321 rows, 132300 columns and 3393774 nonzeros
# Model fingerprint: 0x71860c04
# Variable types: 88200 continuous, 44100 integer (44100 binary)
# Coefficient statistics:
#   Matrix range     [9e-04, 8e+03]
#   Objective range  [9e-04, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+03]
#
# Warning: Completing partial solution with 44022 unfixed non-continuous variables out of 44100
# User MIP start produced solution with objective 294.343 (0.47s)
# Loaded user MIP start with objective 294.343
#
# Presolve removed 1882 rows and 3051 columns (presolve time = 5s)...
# Presolve removed 1873 rows and 3042 columns
# Presolve time: 7.22s
# Presolved: 142448 rows, 129258 columns, 3366036 nonzeros
# Variable types: 85959 continuous, 43299 integer (43299 binary)
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root barrier log...
#
# Ordering time: 1.19s
#
# Barrier statistics:
#  Dense cols : 209
#  Free vars  : 278
#  AA' NZ     : 6.726e+05
#  Factor NZ  : 8.266e+06 (roughly 100 MB of memory)
#  Factor Ops : 1.752e+10 (less than 1 second per iteration)
#  Threads    : 8
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -1.61862054e+07  1.11692548e+04  6.56e+01 4.15e+04  5.06e+03    11s
#    1  -9.74677969e+06  2.90963553e+05  3.69e+01 3.39e+04  3.76e+03    11s
#    2  -2.93473946e+06  2.93503490e+04  1.21e-01 3.55e+03  4.05e+02    12s
#    3  -8.96203236e+05  1.82436969e+04  1.86e-03 1.66e+03  1.77e+02    12s
#    4  -5.84378370e+05  7.98191561e+03  9.29e-05 8.70e+02  9.09e+01    12s
#    5  -4.80471919e+05  7.15718552e+02  2.80e-06 5.46e+01  1.12e+01    12s
#    6  -7.13013042e+04  2.63110226e+02  6.65e-08 5.27e+00  1.15e+00    13s
#    7  -1.57153963e+04  3.45649308e+02  1.25e-08 2.99e-01  2.25e-01    13s
#    8  -4.63634690e+03  3.40477621e+02  3.61e-09 1.54e-02  6.77e-02    13s
#    9  -2.44173000e+03  3.23231943e+02  2.04e-09 8.47e-03  3.76e-02    14s
#   10  -9.47662287e+02  2.95590077e+02  1.13e-09 3.86e-03  1.69e-02    14s
#   11  -3.75246951e+02  2.76805814e+02  6.90e-10 2.64e-03  8.86e-03    14s
#   12   8.54908240e+01  2.49804932e+02  8.03e-10 1.16e-03  2.24e-03    14s
#   13   1.57707281e+02  2.37073836e+02  6.36e-10 6.71e-04  1.08e-03    15s
#   14   1.90099698e+02  2.27184218e+02  7.65e-10 2.91e-04  5.06e-04    15s
#   15   2.01583960e+02  2.22244738e+02  5.54e-10 1.17e-04  2.81e-04    15s
#   16   2.08987998e+02  2.20678993e+02  4.05e-10 6.28e-05  1.59e-04    16s
#   17   2.16423176e+02  2.19151860e+02  2.45e-10 1.19e-05  3.71e-05    16s
#   18   2.18414155e+02  2.18728757e+02  4.45e-10 1.51e-06  4.28e-06    16s
#   19   2.18624312e+02  2.18660626e+02  2.73e-10 7.14e-08  4.92e-07    17s
#   20   2.18649540e+02  2.18657419e+02  6.41e-10 4.68e-08  1.07e-07    17s
#   21   2.18656363e+02  2.18656695e+02  1.48e-09 5.32e-09  4.49e-09    17s
#   22   2.18656588e+02  2.18656588e+02  2.57e-10 2.91e-11  4.52e-12    17s
#
# Barrier solved model in 22 iterations and 17.38 seconds (21.37 work units)
# Optimal objective 2.18656588e+02
#
#
# Root crossover log...
#
#      317 DPushes remaining with DInf 1.7742510e-05                17s
#        0 DPushes remaining with DInf 0.0000000e+00                17s
#
#     4707 PPushes remaining with PInf 0.0000000e+00                17s
#        0 PPushes remaining with PInf 0.0000000e+00                17s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 3.4361132e-01     17s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     4948    2.1865803e+02   0.000000e+00   3.436113e-01     17s
#     4952    2.1865757e+02   0.000000e+00   0.000000e+00     17s
# Concurrent spin time: 0.24s
#
# Solved with barrier
#     4952    2.1865757e+02   0.000000e+00   0.000000e+00     18s
#     4953    2.1865659e+02   0.000000e+00   0.000000e+00     18s
# Extra simplex iterations from dual to original model: 1
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#    27335 DPushes remaining with DInf 0.0000000e+00                18s
#        0 DPushes remaining with DInf 0.0000000e+00                18s
#
#     1825 PPushes remaining with PInf 0.0000000e+00                18s
#        0 PPushes remaining with PInf 0.0000000e+00                18s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.8521003e-13     18s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    20654    2.1865659e+02   0.000000e+00   0.000000e+00     19s
#
# Root relaxation: objective 2.186566e+02, 20654 iterations, 9.99 seconds (6.56 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  218.65659    0  888  294.34318  218.65659  25.7%     -   35s
#      0     0  221.13510    0  493  294.34318  221.13510  24.9%     -  219s
# H    0     0                     287.9531592  221.13510  23.2%     -  265s
#      0     0  224.23520    0  450  287.95316  224.23520  22.1%     -  468s
#      0     0  224.68893    0  418  287.95316  224.68893  22.0%     -  492s
#      0     0  224.68908    0  429  287.95316  224.68908  22.0%     -  507s
#      0     0  224.86485    0  419  287.95316  224.86485  21.9%     -  676s
#      0     0  224.86528    0  450  287.95316  224.86528  21.9%     -  718s
#      0     0  225.10991    0  497  287.95316  225.10991  21.8%     -  943s
# H    0     0                     280.8331365  225.10991  19.8%     -  956s
#      0     0  225.12493    0  490  280.83314  225.12493  19.8%     - 1184s
#      0     0  225.12493    0  482  280.83314  225.12493  19.8%     - 1205s
#      0     0  225.16222    0  526  280.83314  225.16222  19.8%     - 1452s
#      0     0  225.16858    0  566  280.83314  225.16858  19.8%     - 1708s
#      0     0  225.17035    0  569  280.83314  225.17035  19.8%     - 1777s
#      0     0  225.17035    0  526  280.83314  225.17035  19.8%     - 1810s
#      0     0  225.18721    0  536  280.83314  225.18721  19.8%     - 2182s
#      0     0  225.18723    0  513  280.83314  225.18723  19.8%     - 2410s
#      0     0  225.20533    0  611  280.83314  225.20533  19.8%     - 2777s
# H    0     0                     280.5384008  225.20533  19.7%     - 2899s
#      0     0  225.20555    0  566  280.53840  225.20555  19.7%     - 3029s
#      0     0  225.24210    0  654  280.53840  225.24210  19.7%     - 3356s
#      0     0  225.25220    0  701  280.53840  225.25220  19.7%     - 3719s
#      0     0  225.25233    0  636  280.53840  225.25233  19.7%     - 3808s
#      0     0  225.28136    0  744  280.53840  225.28136  19.7%     - 4117s
# H    0     0                     277.5079069  225.28136  18.8%     - 4119s
# H    0     0                     271.5060441  225.28136  17.0%     - 4120s
# H    0     0                     270.5758858  225.28136  16.7%     - 4121s
#      0     0  225.28366    0  743  270.57589  225.28366  16.7%     - 4251s
#      0     0  225.28884    0  656  270.57589  225.28884  16.7%     - 4337s
#      0     0  225.29413    0  661  270.57589  225.29413  16.7%     - 4397s
#      0     0  225.29609    0  633  270.57589  225.29609  16.7%     - 4427s
#      0     0  225.29735    0  636  270.57589  225.29735  16.7%     - 4462s
#      0     0  225.29735    0  634  270.57589  225.29735  16.7%     - 4489s
#      0     0  225.33671    0  633  270.57589  225.33671  16.7%     - 4928s
#      0     0  225.35092    0  576  270.57589  225.35092  16.7%     - 5258s
#      0     0  225.35467    0  581  270.57589  225.35467  16.7%     - 5357s
#      0     0  225.36010    0  564  270.57589  225.36010  16.7%     - 5460s
#      0     0  225.36071    0  596  270.57589  225.36071  16.7%     - 5529s
#      0     0  225.41592    0  672  270.57589  225.41592  16.7%     - 6171s
# H    0     0                     269.9375157  225.41592  16.5%     - 6175s
# H    0     0                     269.1053839  225.41592  16.2%     - 6179s
#      0     0  225.43195    0  568  269.10538  225.43195  16.2%     - 6338s
#      0     0  225.43338    0  605  269.10538  225.43338  16.2%     - 6467s
#      0     0  225.43427    0  576  269.10538  225.43427  16.2%     - 6528s
#      0     0  225.45870    0  677  269.10538  225.45870  16.2%     - 6731s
#      0     0  225.46195    0  563  269.10538  225.46195  16.2%     - 7015s
#      0     0  225.46283    0  604  269.10538  225.46283  16.2%     - 7150s
#      0     0          -    0       269.10538  225.46283  16.2%     - 7200s
#
# Cutting planes:
#   Gomory: 9
#   Lift-and-project: 1
#   Cover: 8
#   Implied bound: 953
#   MIR: 128
#   Flow cover: 304
#   Flow path: 121
#   Zero half: 21
#   Network: 3
#   RLT: 229
#   Relax-and-lift: 5
#
# Explored 1 nodes (2679812 simplex iterations) in 7200.11 seconds (13724.57 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 9: 269.105 269.938 270.576 ... 294.343
#
# Time limit reached
# Best objective 2.691053839289e+02, best bound 2.254628319619e+02, gap 16.2176%
# [(0, 5), (5, 8), (8, 10), (9, 0), (10, 9)]
# [(0, 7), (7, 19), (18, 22), (19, 18), (21, 23), (22, 21), (23, 47), (45, 0), (47, 45)]
# [(0, 42), (6, 11), (11, 12), (12, 0), (38, 63), (40, 68), (41, 40), (42, 43), (43, 41), (63, 6), (68, 38)]
# [(0, 17), (17, 48), (24, 0), (27, 24), (32, 33), (33, 27), (48, 49), (49, 50), (50, 56), (56, 32)]
# [(0, 46), (2, 3), (3, 15), (14, 52), (15, 14), (46, 2), (52, 60), (54, 0), (60, 54)]
# [(0, 59), (16, 30), (20, 0), (25, 28), (26, 16), (28, 20), (29, 25), (30, 31), (31, 29), (51, 53), (53, 26), (59, 51)]
# [(0, 35), (1, 58), (35, 62), (55, 1), (57, 0), (58, 57), (62, 55)]
# [(0, 64), (4, 39), (37, 4), (39, 66), (61, 0), (64, 37), (66, 67), (67, 61)]
# [(0, 65), (13, 69), (34, 13), (36, 44), (44, 0), (65, 34), (69, 36)]
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-12-12.xlsx', 1)
# INDEX: 134
# Instância Instancias Clusters\tabelas_2023-12-12.xlsx - Cluster 1 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-12-12.xlsx', 3)
# INDEX: 135
# Instância Instancias Clusters\tabelas_2023-12-12.xlsx - Cluster 3 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-12-12.xlsx', 2)
# INDEX: 136
# Instância Instancias Clusters\tabelas_2023-12-12.xlsx - Cluster 2 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-12-12.xlsx', 5)
# INDEX: 137
# Instância Instancias Clusters\tabelas_2023-12-12.xlsx - Cluster 5 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-12-14.xlsx', 1)
# INDEX: 138
# Instância Instancias Clusters\tabelas_2023-12-14.xlsx - Cluster 1 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-12-14.xlsx', 6)
# INDEX: 139
# Instância Instancias Clusters\tabelas_2023-12-14.xlsx - Cluster 6 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-12-14.xlsx', 5)
# INDEX: 140
# Instância Instancias Clusters\tabelas_2023-12-14.xlsx - Cluster 5 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-12-14.xlsx', 4)
# INDEX: 141
# Instância Instancias Clusters\tabelas_2023-12-14.xlsx - Cluster 4 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-12-14.xlsx', 2)
# INDEX: 142
# Instância Instancias Clusters\tabelas_2023-12-14.xlsx - Cluster 2 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2023-12-14.xlsx', 3)
# INDEX: 143
# Instância Instancias Clusters\tabelas_2023-12-14.xlsx - Cluster 3 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2024-01-02.xlsx', 4)
# INDEX: 144
# Instância Instancias Clusters\tabelas_2024-01-02.xlsx - Cluster 4 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2024-01-02.xlsx', 3)
# INDEX: 145
# Instância Instancias Clusters\tabelas_2024-01-02.xlsx - Cluster 3 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2024-01-02.xlsx', 1)
# INDEX: 146
# Instância Instancias Clusters\tabelas_2024-01-02.xlsx - Cluster 1 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2024-01-02.xlsx', 5)
# INDEX: 147
# Instância Instancias Clusters\tabelas_2024-01-02.xlsx - Cluster 5 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2024-01-02.xlsx', 2)
# INDEX: 148
# Instância Instancias Clusters\tabelas_2024-01-02.xlsx - Cluster 2 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2024-01-05.xlsx', 2)
# INDEX: 149
# Instância Instancias Clusters\tabelas_2024-01-05.xlsx - Cluster 2 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2024-01-05.xlsx', 5)
# INDEX: 150
# Instância Instancias Clusters\tabelas_2024-01-05.xlsx - Cluster 5 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2024-01-05.xlsx', 6)
# INDEX: 151
# Instância Instancias Clusters\tabelas_2024-01-05.xlsx - Cluster 6 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2024-01-05.xlsx', 3)
# INDEX: 152
# Instância Instancias Clusters\tabelas_2024-01-05.xlsx - Cluster 3 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2024-01-05.xlsx', 4)
# INDEX: 153
# Instância Instancias Clusters\tabelas_2024-01-05.xlsx - Cluster 4 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2024-01-05.xlsx', 1)
# INDEX: 154
# Instância Instancias Clusters\tabelas_2024-01-05.xlsx - Cluster 1 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2024-01-06.xlsx', 1)
# INDEX: 155
# Instância Instancias Clusters\tabelas_2024-01-06.xlsx - Cluster 1 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2024-01-06.xlsx', 6)
# INDEX: 156
# Instância Instancias Clusters\tabelas_2024-01-06.xlsx - Cluster 6 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2024-01-06.xlsx', 3)
# INDEX: 157
# Instância Instancias Clusters\tabelas_2024-01-06.xlsx - Cluster 3 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2024-01-06.xlsx', 2)
# INDEX: 158
# Instância Instancias Clusters\tabelas_2024-01-06.xlsx - Cluster 2 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2024-01-06.xlsx', 4)
# INDEX: 159
# Instância Instancias Clusters\tabelas_2024-01-06.xlsx - Cluster 4 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2024-01-06.xlsx', 5)
# INDEX: 160
# Instância Instancias Clusters\tabelas_2024-01-06.xlsx - Cluster 5 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2024-01-09.xlsx', 3)
# INDEX: 161
# Instância Instancias Clusters\tabelas_2024-01-09.xlsx - Cluster 3 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2024-01-09.xlsx', 1)
# INDEX: 162
# Instância Instancias Clusters\tabelas_2024-01-09.xlsx - Cluster 1 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2024-01-09.xlsx', 7)
# INDEX: 163
# Instância Instancias Clusters\tabelas_2024-01-09.xlsx - Cluster 7 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2024-01-09.xlsx', 2)
# INDEX: 164
# Instância Instancias Clusters\tabelas_2024-01-09.xlsx - Cluster 2 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2024-01-09.xlsx', 4)
# INDEX: 165
# Instância Instancias Clusters\tabelas_2024-01-09.xlsx - Cluster 4 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2024-01-09.xlsx', 8)
# INDEX: 166
# Instância Instancias Clusters\tabelas_2024-01-09.xlsx - Cluster 8 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2024-01-09.xlsx', 5)
# INDEX: 167
# Instância Instancias Clusters\tabelas_2024-01-09.xlsx - Cluster 5 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2024-01-09.xlsx', 6)
# INDEX: 168
# Instância Instancias Clusters\tabelas_2024-01-09.xlsx - Cluster 6 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2024-02-20.xlsx', 2)
# INDEX: 169
# Instância Instancias Clusters\tabelas_2024-02-20.xlsx - Cluster 2 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2024-02-20.xlsx', 1)
# INDEX: 170
# Instância Instancias Clusters\tabelas_2024-02-20.xlsx - Cluster 1 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2024-02-20.xlsx', 5)
# INDEX: 171
# Instância Instancias Clusters\tabelas_2024-02-20.xlsx - Cluster 5 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2024-02-20.xlsx', 4)
# INDEX: 172
# Instância Instancias Clusters\tabelas_2024-02-20.xlsx - Cluster 4 já processada. Pulando...
#
# INSTANCIA: ('Instancias Clusters\\tabelas_2024-02-20.xlsx', 3)
# INDEX: 173
# Instância Instancias Clusters\tabelas_2024-02-20.xlsx - Cluster 3 já processada. Pulando...
