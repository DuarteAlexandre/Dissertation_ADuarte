# %%
import pandas as pd
import numpy as np
import time
import os
from openpyxl import load_workbook
from glob import glob
from ModeloMatematico1_MultiplosEc import ModeloMatematico as ModelFleetSize_MultiplosEc
from ModeloMatematico2_MultiplosEc import ModeloMatematico as ModelConsumo_MultiplosEc
from ModeloMatematico1_Fisico import ModeloMatematico as ModelFleetSize_Fisico
from ModeloMatematico2_Fisico import ModeloMatematico as ModelConsumo_Fisico

# %%
# Caminho do arquivo Excel
caminho_arquivo = f"./Resultados_Hibrido.xlsx"

# Ler todas as abas
dados = []
instancias = []
resumo = []
# Mostrar os nomes das abas e seus respectivos DataFrames
atualizar = True
if atualizar:
    abas = pd.read_excel(caminho_arquivo, sheet_name=None)
    for nome_aba, df in abas.items():
        #print(f'Aba: {nome_aba}')
        #print(df.head())  # Exibe as primeiras linhas do DataFrame
        dado = df.to_dict(orient="records")
        #print(dado)
        if nome_aba != "resumo":
            dados.append(dado)
            instancias.append(nome_aba)
        else:
            resumo = dado

# %%
# Funcao
def Get_Di(Pontos, file):
    df = pd.read_excel("DELIVERIES.xlsx")
    df['data'] = pd.to_datetime(df['tour_date'])
    df['dia'] = df['data'].dt.day
    df['mes'] = df['data'].dt.month
    df['ano'] = df['data'].dt.year

    data = str(file).replace(".xlsx", "")[-10:]
    dia = int(data[-2:])
    mes = int(data[-5:-3])
    ano = int(data[:4])
    
    df_demandas = df[df['ano']==ano]
    df_demandas = df_demandas[df_demandas['mes']==mes]
    df_demandas = df_demandas[df_demandas['dia']==dia]
    dict_demanda = df_demandas.to_dict(orient="records")
    
    d_i = np.zeros(len(Pontos))

    for d in dict_demanda:
        client_id = d["client_id"]
        weight_kg = d["weight_kg"]

        if client_id not in Pontos: continue
        i = Pontos.index(client_id)
        d_i[i] = weight_kg
        
    

    return d_i

# %%
def combinacoes_2_a_2(conjunto, k=2):
    # Converte o conjunto para uma lista para facilitar o acesso por índice
    lista = list(conjunto)
    resultado = []
    
    def gerar_combinacoes(prefixo, inicio, k=2):
        # Quando o prefixo tem 2 elementos, adiciona ao resultado
        if len(prefixo) == k:
            resultado.append(tuple(prefixo))
            return
        
        # Loop para escolher os elementos
        for i in range(inicio, len(lista)):
            # Adiciona o próximo elemento ao prefixo e chama recursivamente
            gerar_combinacoes(prefixo + [lista[i]], i + 1, k)

    # Chama a função recursiva inicial
    gerar_combinacoes([], 0, k)
    return resultado

def CriarConjuntoCorteHiperplane(qntClientes):
    S = []
    __S = lambda __n: [list(s) for s in combinacoes_2_a_2(list(range(1, qntClientes+1)), __n)]
    for __n in range(2, 4):
        list_S = __S(__n)
        S += list_S
        
    return S

# %%
# Leitura de Arquivos
CONJUNTO_CORTES = dict()

INSTANCIAS = []

for file in glob("Instancias Clusters/*.xlsx"):
    try:
        df = pd.read_excel(file, "Pontos")

        def converter_id(valor):
            if valor == "CD":
                return valor  # Retorna "CD" sem alterar
            try:
                return float(valor)  # Tenta converter o valor para número
            except ValueError:
                return valor  # Se não for possível converter, retorna o valor original

        # Aplicar a função à coluna 'ID'
        df['ID'] = df['ID'].apply(converter_id)

        df_Energia = pd.read_excel(file, "Tabela Energia", usecols=['origin', 'destination', 'distancia (m)', 'e_ij_fixo', 'e_ij'])
        dict_Energia = df_Energia.to_dict(orient='records')    
        clusters = df["Cluster"].unique()

        CD = df[df["ID"]=="CD"]
        CD = list(CD["ID"].to_list())[0]
        for cluster in clusters:
            if cluster == "CD": continue
            clientes = df[df["Cluster"]==cluster]
            clientes = list(clientes["ID"].to_list())

            if len(clientes) not in CONJUNTO_CORTES:
                print("CRIANDO CORTES", len(clientes))
                print(file)
                CONJUNTO_CORTES[len(clientes)] = CriarConjuntoCorteHiperplane(len(clientes))
            
            # PONTOS
            DADO = {"file": file, "cluster": cluster, "PONTOS": [CD] + clientes}
            

            # DADOS DISTANCIA
            d_ij = np.zeros(shape=(len(DADO["PONTOS"]), len(DADO["PONTOS"])))
            e_FIXO_ij = np.zeros(shape=(len(DADO["PONTOS"]), len(DADO["PONTOS"])))
            e_ij = np.zeros(shape=(len(DADO["PONTOS"]), len(DADO["PONTOS"])))

            for d in dict_Energia:
                i = d["origin"]
                j = d["destination"]
                
                if i not in DADO["PONTOS"]: continue
                if j not in DADO["PONTOS"]: continue
                
                idx_i = DADO["PONTOS"].index(i)
                idx_j = DADO["PONTOS"].index(j)

                d_ij[idx_i, idx_j] = d["distancia (m)"]
                e_FIXO_ij[idx_i, idx_j] = d["e_ij_fixo"] 
                e_ij[idx_i, idx_j] = d["e_ij"]

            d_ij[d_ij == 0] = np.inf
            e_FIXO_ij[e_FIXO_ij == 0] = np.inf
            e_ij[e_ij == 0] = np.inf
            
            # ATENCAO TAXA DE AUMENTO DE DISTANCIA ABAIXO:
            d_ij = d_ij / 1000 * 1.2215
            DADO["d_ij"] = d_ij
            DADO["e_fixo_ij"] = e_FIXO_ij
            DADO["e_ij"] = e_ij
            
            DADO["d_i"] = Get_Di(DADO["PONTOS"], file)
            INSTANCIAS.append(DADO.copy())
    except:
        print("FALHA EM UM ARQUIVO!!!")
        print(file)
    try:
        del df, df_Energia, dict_Energia, clusters, CD, clientes, d_ij, e_FIXO_ij, e_ij, DADO
    except:
        pass
# Out:
# CRIANDO CORTES 58
# Instancias Clusters\tabelas_2023-09-06.xlsx
# CRIANDO CORTES 22
# Instancias Clusters\tabelas_2023-09-06.xlsx
# CRIANDO CORTES 48
# Instancias Clusters\tabelas_2023-09-06.xlsx
# CRIANDO CORTES 37
# Instancias Clusters\tabelas_2023-09-06.xlsx
# CRIANDO CORTES 49
# Instancias Clusters\tabelas_2023-09-06.xlsx
# CRIANDO CORTES 31
# Instancias Clusters\tabelas_2023-09-15.xlsx
# CRIANDO CORTES 40
# Instancias Clusters\tabelas_2023-09-15.xlsx
# CRIANDO CORTES 64
# Instancias Clusters\tabelas_2023-09-15.xlsx
# CRIANDO CORTES 35
# Instancias Clusters\tabelas_2023-09-15.xlsx
# CRIANDO CORTES 34
# Instancias Clusters\tabelas_2023-09-20.xlsx
# CRIANDO CORTES 84
# Instancias Clusters\tabelas_2023-09-20.xlsx
# CRIANDO CORTES 60
# Instancias Clusters\tabelas_2023-09-20.xlsx
# CRIANDO CORTES 36
# Instancias Clusters\tabelas_2023-09-20.xlsx
# CRIANDO CORTES 13
# Instancias Clusters\tabelas_2023-09-20.xlsx
# CRIANDO CORTES 53
# Instancias Clusters\tabelas_2023-09-22.xlsx
# CRIANDO CORTES 50
# Instancias Clusters\tabelas_2023-09-22.xlsx
# CRIANDO CORTES 30
# Instancias Clusters\tabelas_2023-09-22.xlsx
# CRIANDO CORTES 33
# Instancias Clusters\tabelas_2023-10-11.xlsx
# CRIANDO CORTES 72
# Instancias Clusters\tabelas_2023-10-11.xlsx
# CRIANDO CORTES 55
# Instancias Clusters\tabelas_2023-10-11.xlsx
# CRIANDO CORTES 20
# Instancias Clusters\tabelas_2023-10-11.xlsx
# CRIANDO CORTES 17
# Instancias Clusters\tabelas_2023-10-17.xlsx
# CRIANDO CORTES 65
# Instancias Clusters\tabelas_2023-10-17.xlsx
# CRIANDO CORTES 42
# Instancias Clusters\tabelas_2023-10-17.xlsx
# CRIANDO CORTES 28
# Instancias Clusters\tabelas_2023-10-20.xlsx
# CRIANDO CORTES 79
# Instancias Clusters\tabelas_2023-10-21.xlsx
# CRIANDO CORTES 38
# Instancias Clusters\tabelas_2023-10-21.xlsx
# CRIANDO CORTES 39
# Instancias Clusters\tabelas_2023-10-26.xlsx
# CRIANDO CORTES 29
# Instancias Clusters\tabelas_2023-10-26.xlsx
# CRIANDO CORTES 82
# Instancias Clusters\tabelas_2023-11-01.xlsx
# CRIANDO CORTES 26
# Instancias Clusters\tabelas_2023-11-01.xlsx
# CRIANDO CORTES 59
# Instancias Clusters\tabelas_2023-11-04.xlsx
# CRIANDO CORTES 27
# Instancias Clusters\tabelas_2023-11-04.xlsx
# CRIANDO CORTES 67
# Instancias Clusters\tabelas_2023-11-07.xlsx
# CRIANDO CORTES 73
# Instancias Clusters\tabelas_2023-11-07.xlsx
# CRIANDO CORTES 8
# Instancias Clusters\tabelas_2023-11-07.xlsx
# CRIANDO CORTES 62
# Instancias Clusters\tabelas_2023-11-14.xlsx
# CRIANDO CORTES 44
# Instancias Clusters\tabelas_2023-11-14.xlsx
# CRIANDO CORTES 24
# Instancias Clusters\tabelas_2023-11-17.xlsx
# CRIANDO CORTES 66
# Instancias Clusters\tabelas_2023-11-17.xlsx
# CRIANDO CORTES 52
# Instancias Clusters\tabelas_2023-11-17.xlsx
# CRIANDO CORTES 19
# Instancias Clusters\tabelas_2023-11-22.xlsx
# CRIANDO CORTES 71
# Instancias Clusters\tabelas_2023-11-24.xlsx
# CRIANDO CORTES 21
# Instancias Clusters\tabelas_2023-11-24.xlsx
# CRIANDO CORTES 51
# Instancias Clusters\tabelas_2023-11-25.xlsx
# CRIANDO CORTES 23
# Instancias Clusters\tabelas_2023-11-25.xlsx
# CRIANDO CORTES 18
# Instancias Clusters\tabelas_2023-11-28.xlsx
# CRIANDO CORTES 87
# Instancias Clusters\tabelas_2023-11-29.xlsx
# CRIANDO CORTES 25
# Instancias Clusters\tabelas_2023-11-29.xlsx
# CRIANDO CORTES 41
# Instancias Clusters\tabelas_2023-11-30.xlsx
# CRIANDO CORTES 43
# Instancias Clusters\tabelas_2023-11-30.xlsx
# CRIANDO CORTES 47
# Instancias Clusters\tabelas_2023-11-30.xlsx
# CRIANDO CORTES 46
# Instancias Clusters\tabelas_2023-12-01.xlsx
# CRIANDO CORTES 54
# Instancias Clusters\tabelas_2023-12-01.xlsx
# CRIANDO CORTES 32
# Instancias Clusters\tabelas_2023-12-02.xlsx
# CRIANDO CORTES 63
# Instancias Clusters\tabelas_2023-12-02.xlsx
# CRIANDO CORTES 85
# Instancias Clusters\tabelas_2023-12-06.xlsx
# CRIANDO CORTES 68
# Instancias Clusters\tabelas_2023-12-06.xlsx
# CRIANDO CORTES 12
# Instancias Clusters\tabelas_2023-12-06.xlsx
# CRIANDO CORTES 93
# Instancias Clusters\tabelas_2023-12-11.xlsx
# CRIANDO CORTES 69
# Instancias Clusters\tabelas_2023-12-12.xlsx
# CRIANDO CORTES 57
# Instancias Clusters\tabelas_2024-01-05.xlsx
# CRIANDO CORTES 45
# Instancias Clusters\tabelas_2024-01-06.xlsx
# CRIANDO CORTES 78
# Instancias Clusters\tabelas_2024-01-09.xlsx
# CRIANDO CORTES 83
# Instancias Clusters\tabelas_2024-02-20.xlsx

# %%
def vrp_vizinho_mais_proximo(pontos, num_veiculos, distancia, d_i):
    rotas = [[] for _ in range(num_veiculos)]  # Listas de rotas para cada veículo
    num_clientes = len(pontos)
    d_i = np.array(d_i)

    # Adiciona o ponto de partida (depósito) como o primeiro ponto
    deposito = pontos[0]
    clientes = pontos[1:].copy()  # Clientes são todos os pontos exceto o depósito
    
    for i in range(num_veiculos):
        rota = [deposito]  # Começa no depósito
        distancia_total = 0
        
        while clientes:
            ultimo_ponto = pontos[rota[-1]]
            # Encontra o cliente mais próximo
            
            proximo_cliente = min(clientes, key=lambda c: distancia[ultimo_ponto, c])
            #print(proximo_cliente)
            if distancia[ultimo_ponto, proximo_cliente] == np.inf:
                break
            elif d_i[rota+[proximo_cliente]].sum() > 7650:
                distancia[ultimo_ponto, proximo_cliente] = np.inf
            else:
                distancia_total += distancia[ultimo_ponto, proximo_cliente]
                clientes.remove(proximo_cliente)
                # Adiciona o índice do cliente na rota
                rota.append(pontos.index(proximo_cliente))

        rota.append(deposito)  # Retorna ao depósito
        rotas[i] = rota

    return rotas

# %%
def substituir_inf_nan(instancia):
    for key in ['d_ij', 'e_fixo_ij', 'e_ij', 'd_i']:
        if key in instancia:
            instancia[key] = np.nan_to_num(instancia[key], nan=1000, posinf=1000, neginf=1000)
    return instancia

INSTANCIAS = [substituir_inf_nan(instancia) for instancia in INSTANCIAS]

# %%
from copy import copy
rotas_iniciais = []
for idx, instancia in enumerate(INSTANCIAS):
    Pontos = instancia["PONTOS"]
    d_i = instancia["d_i"]
    d_ij = instancia["d_ij"]

    N = list(range(len(Pontos))) # 1 CD e 10 CLientes

    Q = 7920 # CAPACIDADE LIQUIDA DO VEICULO (KG)

    rotas = vrp_vizinho_mais_proximo(N, 20, copy(d_ij), d_i)
    #print(rotas)

    # VALIDAR ROTAS:
    
    d_i = np.array(d_i)
    rotas_dict = {"x_ijk": dict(), "f_ijk": dict(), "g_ijk": dict()}
    k = 0
    for rota in rotas:
        if len(rota)==2: continue
        #print(d_i[rota])
        if d_i[rota].sum() > Q:
            print("INVALIDO CARGA")
        bateria = 105
        for i_j in range(1, len(rota)):
            i = rota[i_j-1]
            j = rota[i_j]
            if i == 0:
                bateria -= d_ij[0, j] * 0.74
            elif j == 0:
                bateria -= d_ij[i, 0] * 0.57
            else:
                bateria -= d_ij[i, j] * 1.0

            rotas_dict["x_ijk"][(i,j,k)] = 1
    
        if bateria < 20:
            print("INVALIDO BATERIA")
            print(idx)

        k+=1
    #print(rotas_dict)

    rotas_iniciais.append(rotas_dict)

# %%
len(rotas_iniciais)
# Out:
# 174

# %%
file_path = "./Resultados_Hibrido.xlsx"

if os.path.exists(file_path):
    with pd.ExcelFile(file_path) as xls:
        if "resumo" in xls.sheet_names:
            existing_summary = pd.read_excel(xls, sheet_name="resumo")
        else:
            existing_summary = pd.DataFrame()
else:
    existing_summary = pd.DataFrame()


processed_combinations = [
    (file, cluster) for file, cluster in zip(existing_summary["File"], existing_summary["cluster"])
] if not existing_summary.empty else []

# %%
len(processed_combinations)
# Out:
# 72

# %%
# Caminho do arquivo Excel
file_path = "./Resultados_Hibrido.xlsx"

# %%
# PROCEDIMENTO:

import logging
import os
import traceback

log_filename = "Instancias_Hibrido.log"

# Configuração básica do logger
logging.basicConfig(
    filename=log_filename,         # Nome do arquivo de log
    level=logging.INFO,             # Nível de log (INFO, DEBUG, ERROR, etc.)
    format="%(asctime)s - %(levelname)s - %(message)s",  # Formato do log
)

dados = []
resumo = []

for idx, inst in enumerate(INSTANCIAS, start=0):

    inst_key = (inst["file"], inst["cluster"])
    print("Instância atual:", inst_key)

    # Verificar se a combinação file + cluster já foi processada
    if inst_key in processed_combinations:
        print(f"Instância {inst['file']} - Cluster {inst['cluster']} já processada. Pulando...")
        print(idx)
        continue

    # MODELO MULTIPLOS PARAMETROS MACROSCOPICOS
    # TAMANHO DE FROTA OTIMO:
    C = range(1, len(inst["PONTOS"]))
    N = range(0, len(inst["PONTOS"]))
    A = [(i,j) for i in N for j in N if i!=j]
    K = range(9)
    Q = 7920
    d_i = inst["d_i"]
    d_ij = inst["d_ij"]
    e_ij = inst['e_ij']
    e_FIXO_ij = inst['e_fixo_ij']
    SOH = 0.95
    Bmax = 105
    Bmin = 20
    Error = 2.42

    rotainicial = rotas_iniciais[idx]
    #print(rotainicial["x_ijk"])

    S = CONJUNTO_CORTES[len(C)]

    t_total = time.time()

    try:
        # ETAPA 1
        _m, x_ijk, f_ijk, g_ijk, gap, FleetSize = ModelFleetSize_Fisico(C, N, A, K, Q, d_i, SOH, Bmax, Bmin, Error, e_FIXO_ij, e_ij, rotainicial, S)
        FleetSize = int(FleetSize)
        #print(FleetSize)

        # ETAPA 2
        tempo_opt = time.time()

        _rotainicial = {"x_ijk": dict(), "f_ijk": dict(), "g_ijk": dict()}
        K_disp = []
        for i, j in A:
            for k in K:
                if x_ijk[i,j,k].X > 0.1:
                    _rotainicial["x_ijk"][(i,j,k)] = 1
                    if k not in K_disp: K_disp.append(k)

        rotainicial = {"x_ijk": dict(), "f_ijk": dict(), "g_ijk": dict()}

        for i,j,k in _rotainicial["x_ijk"]:
            if _rotainicial["x_ijk"][(i,j,k)] == 1:
                rotainicial["x_ijk"][(i,j,K_disp.index(k))] = 1

        del _rotainicial

        K = range(FleetSize)
        _m, x_ijk, f_ijk, g_ijk, gap = ModelConsumo_Fisico(C, N, A, K, Q, d_i, SOH, Bmax, Bmin, Error, FleetSize, e_FIXO_ij, e_ij, rotainicial, S)


        # PROCESSAR DADOS
        resp = {k: [] for k in K}
        dados.append([])
        
        dist = 0
                        
        consumo = _m.objVal

        lotacao_k = []
        tam_frota = 0
        for k in K:
            for j in C:
                if x_ijk[0,j,k].X > 0.1:
                    tam_frota += 1
                    lotacao_k.append(f_ijk[0,j,k].X)


        consumos_k = []
        distancias_k = []

        for k in K:  
            somatorio_consumo = 0
            somatorio_distancia = 0
            for i,j in A:  
                x_ijk_value = x_ijk[i, j, k].X  
                f_ijk_value = f_ijk[i, j, k].X 

                e_FIXO_ij_value = e_FIXO_ij[i, j]
                e_ij_value = e_ij[i, j]  
                d_ij_value = d_ij[i,j]
                
                somatorio_consumo += (x_ijk_value * e_FIXO_ij_value + e_ij_value * f_ijk_value)*1.2215 # COEFICIENTE DE 22% DE AJUSTE (ROTA PRATICADA > ROTA PLANEJADA)
                somatorio_distancia += (x_ijk_value * d_ij_value) # DISTÂNCIA JÁ FOI AJUSTADA ANTERIORMENTE

            consumos_k.append(somatorio_consumo)
            distancias_k.append(somatorio_distancia)

        for k in K:
            for i,j in A:
                if x_ijk[i,j,k].X > 0.1: 
                    resp[k].append((i,j))
                    dados[-1].append({"variavel": "x_ijk", "i": i, "j": j, "k": k, "value": x_ijk[i,j,k].X, "obs": ""})
                    dados[-1].append({"variavel": "f_ijk", "i": i, "j": j, "k": k, "value": f_ijk[i,j,k].X, "obs": ""})
                    dados[-1].append({"variavel": "g_ijk", "i": i, "j": j, "k": k, "value": g_ijk[i,j,k].X, "obs": ""})
                    dist += d_ij[i,j]*x_ijk[i,j,k].X
                else:
                    if f_ijk[i,j,k].X > 0.1 or g_ijk[i,j,k].X>0.1:
                        dados[-1].append({"variavel": "x_ijk", "i": i, "j": j, "k": k, "value": x_ijk[i,j,k].X, "obs": "Sim"})
                        dados[-1].append({"variavel": "f_ijk", "i": i, "j": j, "k": k, "value": f_ijk[i,j,k].X, "obs": "Sim"})
                        dados[-1].append({"variavel": "g_ijk", "i": i, "j": j, "k": k, "value": g_ijk[i,j,k].X, "obs": "Sim"})
        
        resumo.append({"File": inst["file"], "cluster": inst["cluster"], "lotacao_k": lotacao_k, "dist": dist, "dist_k": [float(d) for d in distancias_k],"consumo": consumo*1.2215, "consumo_k": [float(c) for c in consumos_k], "FleetSize": tam_frota, "t_total": time.time() - t_total, "tempo Opt": time.time() - tempo_opt, "tempo fleet": tempo_opt - t_total, "gap": gap})
        t = time.time()
        for k in K:
            if not len(resp[k]): continue
            print(resp[k])

        del _m
        del x_ijk
        del f_ijk
        del g_ijk
        del gap

        tam_frota = 0

        if os.path.exists(file_path):
            wb = load_workbook(file_path)
            if "resumo" in wb.sheetnames:
                existing_summary = pd.read_excel(file_path, sheet_name="resumo")
            else:
                existing_summary = pd.DataFrame()
        else:
            existing_summary = pd.DataFrame()

        new_summary_df = pd.DataFrame([resumo[-1]])

        if not existing_summary.empty:
            is_duplicate = (
                (existing_summary["File"] == resumo[-1]["File"]) &
                (existing_summary["cluster"] == resumo[-1]["cluster"])
            ).any()
        else:
            is_duplicate = False

        if not is_duplicate:
            existing_summary = pd.concat([existing_summary, new_summary_df], ignore_index=True)

        with pd.ExcelWriter(file_path, engine='openpyxl', mode='a', if_sheet_exists='replace') as writer:
            existing_summary.to_excel(writer, sheet_name="resumo", index=False)

            df = pd.DataFrame(dados[-1])

            sheet_name = f'Instancia_{idx + 1}'

            df.to_excel(writer, sheet_name=sheet_name, index=False)    
                
    except Exception as e:
        print(F"-----------------ERRO NA INSTÂNCIA {inst['file']}-----------------")
        print(f"Detalhes do erro: {str(e)}")  # Mostra o erro no console
        logging.error(f"ERRO NA INSTÂNCIA {inst['file']} - {str(e)}")
        logging.error(traceback.format_exc())  # Adiciona o traceback completo ao log
        pass
# Out:
# Instância atual: ('Instancias Clusters\\tabelas_2023-09-06.xlsx', 5)
# Instância Instancias Clusters\tabelas_2023-09-06.xlsx - Cluster 5 já processada. Pulando...
# 0
# Instância atual: ('Instancias Clusters\\tabelas_2023-09-06.xlsx', 1)
# Instância Instancias Clusters\tabelas_2023-09-06.xlsx - Cluster 1 já processada. Pulando...
# 1
# Instância atual: ('Instancias Clusters\\tabelas_2023-09-06.xlsx', 2)
# Instância Instancias Clusters\tabelas_2023-09-06.xlsx - Cluster 2 já processada. Pulando...
# 2
# Instância atual: ('Instancias Clusters\\tabelas_2023-09-06.xlsx', 3)
# Instância Instancias Clusters\tabelas_2023-09-06.xlsx - Cluster 3 já processada. Pulando...
# 3
# Instância atual: ('Instancias Clusters\\tabelas_2023-09-06.xlsx', 4)
# Instância Instancias Clusters\tabelas_2023-09-06.xlsx - Cluster 4 já processada. Pulando...
# 4
# Instância atual: ('Instancias Clusters\\tabelas_2023-09-15.xlsx', 4)
# Instância Instancias Clusters\tabelas_2023-09-15.xlsx - Cluster 4 já processada. Pulando...
# 5
# Instância atual: ('Instancias Clusters\\tabelas_2023-09-15.xlsx', 2)
# Instância Instancias Clusters\tabelas_2023-09-15.xlsx - Cluster 2 já processada. Pulando...
# 6
# Instância atual: ('Instancias Clusters\\tabelas_2023-09-15.xlsx', 1)
# Instância Instancias Clusters\tabelas_2023-09-15.xlsx - Cluster 1 já processada. Pulando...
# 7
# Instância atual: ('Instancias Clusters\\tabelas_2023-09-15.xlsx', 3)
# Instância Instancias Clusters\tabelas_2023-09-15.xlsx - Cluster 3 já processada. Pulando...
# 8
# Instância atual: ('Instancias Clusters\\tabelas_2023-09-15.xlsx', 5)
# Instância Instancias Clusters\tabelas_2023-09-15.xlsx - Cluster 5 já processada. Pulando...
# 9
# Instância atual: ('Instancias Clusters\\tabelas_2023-09-20.xlsx', 1)
# Instância Instancias Clusters\tabelas_2023-09-20.xlsx - Cluster 1 já processada. Pulando...
# 10
# Instância atual: ('Instancias Clusters\\tabelas_2023-09-20.xlsx', 3)
# Instância Instancias Clusters\tabelas_2023-09-20.xlsx - Cluster 3 já processada. Pulando...
# 11
# Instância atual: ('Instancias Clusters\\tabelas_2023-09-20.xlsx', 4)
# Instância Instancias Clusters\tabelas_2023-09-20.xlsx - Cluster 4 já processada. Pulando...
# 12
# Instância atual: ('Instancias Clusters\\tabelas_2023-09-20.xlsx', 2)
# Instância Instancias Clusters\tabelas_2023-09-20.xlsx - Cluster 2 já processada. Pulando...
# 13
# Instância atual: ('Instancias Clusters\\tabelas_2023-09-20.xlsx', 5)
# Instância Instancias Clusters\tabelas_2023-09-20.xlsx - Cluster 5 já processada. Pulando...
# 14
# Instância atual: ('Instancias Clusters\\tabelas_2023-09-22.xlsx', 3)
# Instância Instancias Clusters\tabelas_2023-09-22.xlsx - Cluster 3 já processada. Pulando...
# 15
# Instância atual: ('Instancias Clusters\\tabelas_2023-09-22.xlsx', 1)
# Instância Instancias Clusters\tabelas_2023-09-22.xlsx - Cluster 1 já processada. Pulando...
# 16
# Instância atual: ('Instancias Clusters\\tabelas_2023-09-22.xlsx', 4)
# Instância Instancias Clusters\tabelas_2023-09-22.xlsx - Cluster 4 já processada. Pulando...
# 17
# Instância atual: ('Instancias Clusters\\tabelas_2023-09-22.xlsx', 5)
# Instância Instancias Clusters\tabelas_2023-09-22.xlsx - Cluster 5 já processada. Pulando...
# 18
# Instância atual: ('Instancias Clusters\\tabelas_2023-09-22.xlsx', 2)
# Instância Instancias Clusters\tabelas_2023-09-22.xlsx - Cluster 2 já processada. Pulando...
# 19
# Instância atual: ('Instancias Clusters\\tabelas_2023-10-11.xlsx', 5)
# Instância Instancias Clusters\tabelas_2023-10-11.xlsx - Cluster 5 já processada. Pulando...
# 20
# Instância atual: ('Instancias Clusters\\tabelas_2023-10-11.xlsx', 1)
# Instância Instancias Clusters\tabelas_2023-10-11.xlsx - Cluster 1 já processada. Pulando...
# 21
# Instância atual: ('Instancias Clusters\\tabelas_2023-10-11.xlsx', 2)
# Instância Instancias Clusters\tabelas_2023-10-11.xlsx - Cluster 2 já processada. Pulando...
# 22
# Instância atual: ('Instancias Clusters\\tabelas_2023-10-11.xlsx', 3)
# Instância Instancias Clusters\tabelas_2023-10-11.xlsx - Cluster 3 já processada. Pulando...
# 23
# Instância atual: ('Instancias Clusters\\tabelas_2023-10-11.xlsx', 4)
# Instância Instancias Clusters\tabelas_2023-10-11.xlsx - Cluster 4 já processada. Pulando...
# 24
# Instância atual: ('Instancias Clusters\\tabelas_2023-10-17.xlsx', 4)
# Instância Instancias Clusters\tabelas_2023-10-17.xlsx - Cluster 4 já processada. Pulando...
# 25
# Instância atual: ('Instancias Clusters\\tabelas_2023-10-17.xlsx', 5)
# Instância Instancias Clusters\tabelas_2023-10-17.xlsx - Cluster 5 já processada. Pulando...
# 26
# Instância atual: ('Instancias Clusters\\tabelas_2023-10-17.xlsx', 1)
# Instância Instancias Clusters\tabelas_2023-10-17.xlsx - Cluster 1 já processada. Pulando...
# 27
# Instância atual: ('Instancias Clusters\\tabelas_2023-10-17.xlsx', 2)
# Instância Instancias Clusters\tabelas_2023-10-17.xlsx - Cluster 2 já processada. Pulando...
# 28
# Instância atual: ('Instancias Clusters\\tabelas_2023-10-17.xlsx', 3)
# Instância Instancias Clusters\tabelas_2023-10-17.xlsx - Cluster 3 já processada. Pulando...
# 29
# Instância atual: ('Instancias Clusters\\tabelas_2023-10-20.xlsx', 4)
# Instância Instancias Clusters\tabelas_2023-10-20.xlsx - Cluster 4 já processada. Pulando...
# 30
# Instância atual: ('Instancias Clusters\\tabelas_2023-10-20.xlsx', 3)
# Instância Instancias Clusters\tabelas_2023-10-20.xlsx - Cluster 3 já processada. Pulando...
# 31
# Instância atual: ('Instancias Clusters\\tabelas_2023-10-20.xlsx', 1)
# Instância Instancias Clusters\tabelas_2023-10-20.xlsx - Cluster 1 já processada. Pulando...
# 32
# Instância atual: ('Instancias Clusters\\tabelas_2023-10-20.xlsx', 5)
# Instância Instancias Clusters\tabelas_2023-10-20.xlsx - Cluster 5 já processada. Pulando...
# 33
# Instância atual: ('Instancias Clusters\\tabelas_2023-10-20.xlsx', 2)
# Instância Instancias Clusters\tabelas_2023-10-20.xlsx - Cluster 2 já processada. Pulando...
# 34
# Instância atual: ('Instancias Clusters\\tabelas_2023-10-21.xlsx', 4)
# Instância Instancias Clusters\tabelas_2023-10-21.xlsx - Cluster 4 já processada. Pulando...
# 35
# Instância atual: ('Instancias Clusters\\tabelas_2023-10-21.xlsx', 2)
# Instância Instancias Clusters\tabelas_2023-10-21.xlsx - Cluster 2 já processada. Pulando...
# 36
# Instância atual: ('Instancias Clusters\\tabelas_2023-10-21.xlsx', 5)
# Instância Instancias Clusters\tabelas_2023-10-21.xlsx - Cluster 5 já processada. Pulando...
# 37
# Instância atual: ('Instancias Clusters\\tabelas_2023-10-21.xlsx', 1)
# Instância Instancias Clusters\tabelas_2023-10-21.xlsx - Cluster 1 já processada. Pulando...
# 38
# Instância atual: ('Instancias Clusters\\tabelas_2023-10-21.xlsx', 3)
# Instância Instancias Clusters\tabelas_2023-10-21.xlsx - Cluster 3 já processada. Pulando...
# 39
# Instância atual: ('Instancias Clusters\\tabelas_2023-10-26.xlsx', 2)
# Instância Instancias Clusters\tabelas_2023-10-26.xlsx - Cluster 2 já processada. Pulando...
# 40
# Instância atual: ('Instancias Clusters\\tabelas_2023-10-26.xlsx', 3)
# Instância Instancias Clusters\tabelas_2023-10-26.xlsx - Cluster 3 já processada. Pulando...
# 41
# Instância atual: ('Instancias Clusters\\tabelas_2023-10-26.xlsx', 4)
# Instância Instancias Clusters\tabelas_2023-10-26.xlsx - Cluster 4 já processada. Pulando...
# 42
# Instância atual: ('Instancias Clusters\\tabelas_2023-10-26.xlsx', 6)
# Instância Instancias Clusters\tabelas_2023-10-26.xlsx - Cluster 6 já processada. Pulando...
# 43
# Instância atual: ('Instancias Clusters\\tabelas_2023-10-26.xlsx', 1)
# Instância Instancias Clusters\tabelas_2023-10-26.xlsx - Cluster 1 já processada. Pulando...
# 44
# Instância atual: ('Instancias Clusters\\tabelas_2023-10-26.xlsx', 5)
# Instância Instancias Clusters\tabelas_2023-10-26.xlsx - Cluster 5 já processada. Pulando...
# 45
# Instância atual: ('Instancias Clusters\\tabelas_2023-11-01.xlsx', 4)
# Instância Instancias Clusters\tabelas_2023-11-01.xlsx - Cluster 4 já processada. Pulando...
# 46
# Instância atual: ('Instancias Clusters\\tabelas_2023-11-01.xlsx', 1)
# Instância Instancias Clusters\tabelas_2023-11-01.xlsx - Cluster 1 já processada. Pulando...
# 47
# Instância atual: ('Instancias Clusters\\tabelas_2023-11-01.xlsx', 2)
# Instância Instancias Clusters\tabelas_2023-11-01.xlsx - Cluster 2 já processada. Pulando...
# 48
# Instância atual: ('Instancias Clusters\\tabelas_2023-11-01.xlsx', 3)
# Instância Instancias Clusters\tabelas_2023-11-01.xlsx - Cluster 3 já processada. Pulando...
# 49
# Instância atual: ('Instancias Clusters\\tabelas_2023-11-01.xlsx', 5)
# Instância Instancias Clusters\tabelas_2023-11-01.xlsx - Cluster 5 já processada. Pulando...
# 50
# Instância atual: ('Instancias Clusters\\tabelas_2023-11-04.xlsx', 2)
# Instância Instancias Clusters\tabelas_2023-11-04.xlsx - Cluster 2 já processada. Pulando...
# 51
# Instância atual: ('Instancias Clusters\\tabelas_2023-11-04.xlsx', 3)
# Instância Instancias Clusters\tabelas_2023-11-04.xlsx - Cluster 3 já processada. Pulando...
# 52
# Instância atual: ('Instancias Clusters\\tabelas_2023-11-04.xlsx', 4)
# Instância Instancias Clusters\tabelas_2023-11-04.xlsx - Cluster 4 já processada. Pulando...
# 53
# Instância atual: ('Instancias Clusters\\tabelas_2023-11-04.xlsx', 1)
# Instância Instancias Clusters\tabelas_2023-11-04.xlsx - Cluster 1 já processada. Pulando...
# 54
# Instância atual: ('Instancias Clusters\\tabelas_2023-11-04.xlsx', 5)
# Instância Instancias Clusters\tabelas_2023-11-04.xlsx - Cluster 5 já processada. Pulando...
# 55
# Instância atual: ('Instancias Clusters\\tabelas_2023-11-07.xlsx', 4)
# Instância Instancias Clusters\tabelas_2023-11-07.xlsx - Cluster 4 já processada. Pulando...
# 56
# Instância atual: ('Instancias Clusters\\tabelas_2023-11-07.xlsx', 1)
# Instância Instancias Clusters\tabelas_2023-11-07.xlsx - Cluster 1 já processada. Pulando...
# 57
# Instância atual: ('Instancias Clusters\\tabelas_2023-11-07.xlsx', 3)
# Instância Instancias Clusters\tabelas_2023-11-07.xlsx - Cluster 3 já processada. Pulando...
# 58
# Instância atual: ('Instancias Clusters\\tabelas_2023-11-07.xlsx', 5)
# Instância Instancias Clusters\tabelas_2023-11-07.xlsx - Cluster 5 já processada. Pulando...
# 59
# Instância atual: ('Instancias Clusters\\tabelas_2023-11-07.xlsx', 2)
# Instância Instancias Clusters\tabelas_2023-11-07.xlsx - Cluster 2 já processada. Pulando...
# 60
# Instância atual: ('Instancias Clusters\\tabelas_2023-11-14.xlsx', 1)
# Instância Instancias Clusters\tabelas_2023-11-14.xlsx - Cluster 1 já processada. Pulando...
# 61
# Instância atual: ('Instancias Clusters\\tabelas_2023-11-14.xlsx', 2)
# Instância Instancias Clusters\tabelas_2023-11-14.xlsx - Cluster 2 já processada. Pulando...
# 62
# Instância atual: ('Instancias Clusters\\tabelas_2023-11-14.xlsx', 3)
# Instância Instancias Clusters\tabelas_2023-11-14.xlsx - Cluster 3 já processada. Pulando...
# 63
# Instância atual: ('Instancias Clusters\\tabelas_2023-11-14.xlsx', 5)
# Instância Instancias Clusters\tabelas_2023-11-14.xlsx - Cluster 5 já processada. Pulando...
# 64
# Instância atual: ('Instancias Clusters\\tabelas_2023-11-14.xlsx', 4)
# Instância Instancias Clusters\tabelas_2023-11-14.xlsx - Cluster 4 já processada. Pulando...
# 65
# Instância atual: ('Instancias Clusters\\tabelas_2023-11-14.xlsx', 6)
# Instância Instancias Clusters\tabelas_2023-11-14.xlsx - Cluster 6 já processada. Pulando...
# 66
# Instância atual: ('Instancias Clusters\\tabelas_2023-11-17.xlsx', 3)
# Instância Instancias Clusters\tabelas_2023-11-17.xlsx - Cluster 3 já processada. Pulando...
# 67
# Instância atual: ('Instancias Clusters\\tabelas_2023-11-17.xlsx', 1)
# Instância Instancias Clusters\tabelas_2023-11-17.xlsx - Cluster 1 já processada. Pulando...
# 68
# Instância atual: ('Instancias Clusters\\tabelas_2023-11-17.xlsx', 5)
# Instância Instancias Clusters\tabelas_2023-11-17.xlsx - Cluster 5 já processada. Pulando...
# 69
# Instância atual: ('Instancias Clusters\\tabelas_2023-11-17.xlsx', 2)
# Instância Instancias Clusters\tabelas_2023-11-17.xlsx - Cluster 2 já processada. Pulando...
# 70
# Instância atual: ('Instancias Clusters\\tabelas_2023-11-17.xlsx', 4)
# Instância Instancias Clusters\tabelas_2023-11-17.xlsx - Cluster 4 já processada. Pulando...
# 71
# Instância atual: ('Instancias Clusters\\tabelas_2023-11-22.xlsx', 5)
# Set parameter Username
# Set parameter LicenseID to value 2600375
# Academic license - for non-commercial use only - expires 2025-12-17
# Set parameter MIPGap to value 0.05
# Set parameter TimeLimit to value 300
# RESTRICOES DE CORTE DE HIPERPLANO
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i5-1235U, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 12 logical processors, using up to 12 threads
#
# Non-default parameters:
# TimeLimit  300
# MIPGap  0.05
#
# Optimize a model with 159558 rows, 143883 columns and 3880224 nonzeros
# Model fingerprint: 0x00f9e0b0
# Variable types: 95922 continuous, 47961 integer (47961 binary)
# Coefficient statistics:
#   Matrix range     [1e-06, 8e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
#
# Warning: Completing partial solution with 47880 unfixed non-continuous variables out of 47961
# User MIP start produced solution with objective 9 (0.75s)
# Loaded user MIP start with objective 9
#
# Presolve removed 1305 rows and 2619 columns (presolve time = 5s)...
# Presolve removed 1296 rows and 2610 columns
# Presolve time: 8.58s
# Presolved: 158262 rows, 141273 columns, 3876354 nonzeros
# Variable types: 93960 continuous, 47313 integer (47313 binary)
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root barrier log...
#
# Ordering time: 2.37s
#
# Barrier statistics:
#  Dense cols : 218
#  Free vars  : 290
#  AA' NZ     : 7.753e+05
#  Factor NZ  : 9.782e+06 (roughly 110 MB of memory)
#  Factor Ops : 2.260e+10 (less than 1 second per iteration)
#  Threads    : 8
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -9.62297500e+05 -1.26661503e-05  3.89e+00 4.23e+04  1.86e+02    15s
#    1  -4.77042216e+05  1.00615740e+04  2.45e+00 3.42e+04  1.42e+02    16s
#
# Barrier performed 1 iterations in 16.09 seconds (14.62 work units)
# Barrier solve interrupted - model solved by another algorithm
#
# Concurrent spin time: 1.31s (can be avoided by choosing Method=3)
#
# Solved with primal simplex
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1942    8.5392449e+00   0.000000e+00   0.000000e+00     16s
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root barrier log...
#
#
# Barrier performed 0 iterations in 18.03 seconds (15.17 work units)
# Barrier solve interrupted - model solved by another algorithm
#
# Concurrent spin time: 0.84s (can be avoided by choosing Method=3)
#
# Solved with dual simplex
#
# Root relaxation: cutoff, 1377 iterations, 7.34 seconds (2.97 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         9.00000    9.00000  0.00%     -   18s
#
# Explored 1 nodes (1377 simplex iterations) in 18.19 seconds (15.16 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 9
#
# Optimal solution found (tolerance 5.00e-02)
# Best objective 9.000000000000e+00, best bound 9.000000000000e+00, gap 0.0000%
# Set parameter MIPGap to value 0.05
# Set parameter TimeLimit to value 7200
# RESTRICOES DE CORTE DE HIPERPLANO
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i5-1235U, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 12 logical processors, using up to 12 threads
#
# Non-default parameters:
# TimeLimit  7200
# MIPGap  0.05
#
# Optimize a model with 159559 rows, 143883 columns and 3880881 nonzeros
# Model fingerprint: 0x6bb5b126
# Variable types: 95922 continuous, 47961 integer (47961 binary)
# Coefficient statistics:
#   Matrix range     [1e-06, 8e+03]
#   Objective range  [1e-06, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
#
# Warning: Completing partial solution with 47880 unfixed non-continuous variables out of 47961
# User MIP start produced solution with objective 237.231 (0.74s)
# User MIP start produced solution with objective 237.231 (0.79s)
# Loaded user MIP start with objective 237.231
#
# Presolve removed 1306 rows and 2619 columns (presolve time = 5s)...
# Presolve removed 1297 rows and 2610 columns
# Presolve time: 8.75s
# Presolved: 158262 rows, 141273 columns, 3876354 nonzeros
# Variable types: 93960 continuous, 47313 integer (47313 binary)
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root barrier log...
#
# Ordering time: 2.61s
#
# Barrier statistics:
#  Dense cols : 218
#  Free vars  : 290
#  AA' NZ     : 7.753e+05
#  Factor NZ  : 9.782e+06 (roughly 110 MB of memory)
#  Factor Ops : 2.260e+10 (roughly 1 second per iteration)
#  Threads    : 8
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -1.04848348e+07  8.18648411e+03  4.24e+01 4.23e+04  2.99e+03    16s
#    1  -6.75842541e+06  1.85271367e+05  1.01e+01 3.49e+04  2.02e+03    16s
#    2  -7.20804469e+06  4.38899451e+04  3.26e-01 5.00e+03  3.54e+02    17s
#    3  -4.41026985e+05  3.21929306e+04  8.87e-03 4.00e+03  2.17e+02    18s
#    4  -4.12415743e+05  9.80422036e+03  5.38e-04 9.57e+02  5.45e+01    18s
#    5  -3.17014935e+05  3.20601896e+03  8.35e-05 1.45e+02  1.07e+01    19s
#    6  -1.21740089e+05  5.53219089e+02  1.02e-07 9.63e+00  1.75e+00    19s
#    7  -1.35280375e+04  3.18860185e+02  8.40e-09 2.37e-01  1.70e-01    20s
#    8  -1.08240861e+03  2.89541755e+02  6.24e-10 1.94e-04  1.65e-02    21s
#    9  -1.02877085e+02  2.33686585e+02  1.66e-09 1.17e-06  4.04e-03    21s
#   10   1.17956101e+02  2.06335932e+02  1.17e-09 4.75e-07  1.06e-03    22s
#   11   1.65750786e+02  1.95427202e+02  6.64e-10 1.52e-07  3.56e-04    23s
#   12   1.78657121e+02  1.91746557e+02  2.54e-10 7.78e-08  1.57e-04    23s
#   13   1.84850125e+02  1.89581410e+02  7.12e-11 3.79e-08  5.68e-05    24s
#   14   1.86303529e+02  1.88610218e+02  2.93e-11 2.02e-08  2.77e-05    24s
#   15   1.86745259e+02  1.88172699e+02  1.76e-11 1.25e-08  1.71e-05    25s
#   16   1.86926017e+02  1.87980018e+02  1.28e-11 9.17e-09  1.26e-05    25s
#
# Barrier performed 16 iterations in 25.16 seconds (17.75 work units)
# Barrier solve interrupted - model solved by another algorithm
#
# Concurrent spin time: 2.88s (can be avoided by choosing Method=3)
#
# Solved with primal simplex
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     8952    1.8745654e+02   0.000000e+00   0.000000e+00     25s
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     8975    1.8745267e+02   0.000000e+00   0.000000e+00     25s
# Extra simplex iterations from dual to original model: 23
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#    35451 DPushes remaining with DInf 0.0000000e+00                26s
#        0 DPushes remaining with DInf 0.0000000e+00                27s
#
#     2299 PPushes remaining with PInf 0.0000000e+00                27s
#        0 PPushes remaining with PInf 0.0000000e+00                27s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 3.8058429e-12     27s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    11824    1.8745267e+02   0.000000e+00   0.000000e+00     28s
#
# Root relaxation: objective 1.874527e+02, 11824 iterations, 16.74 seconds (7.37 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  187.45267    0 1038  237.23115  187.45267  21.0%     -   78s
#      0     0  190.57094    0  590  237.23115  190.57094  19.7%     -  800s
# H    0     0                     235.9703919  190.57094  19.2%     - 1006s
#      0     0  195.86846    0  723  235.97039  195.86846  17.0%     - 1889s
#      0     0  196.48152    0  738  235.97039  196.48152  16.7%     - 2532s
#      0     0  196.54000    0  727  235.97039  196.54000  16.7%     - 2824s
#      0     0  196.54935    0  744  235.97039  196.54935  16.7%     - 2913s
#      0     0  196.54949    0  695  235.97039  196.54949  16.7%     - 2960s
#      0     0  196.60962    0  792  235.97039  196.60962  16.7%     - 4170s
#      0     0  196.64173    0  817  235.97039  196.64173  16.7%     - 4751s
#      0     0  196.64623    0  801  235.97039  196.64623  16.7%     - 4911s
#      0     0  196.64848    0  763  235.97039  196.64848  16.7%     - 5100s
#      0     0  196.64860    0  774  235.97039  196.64860  16.7%     - 5152s
#      0     0  196.82346    0  799  235.97039  196.82346  16.6%     - 6597s
#      0     0          -    0       235.97039  196.82346  16.6%     - 7200s
#
# Cutting planes:
#   Gomory: 21
#   Implied bound: 911
#   MIR: 266
#   Flow cover: 185
#   Flow path: 43
#   Zero half: 1
#   Mod-K: 3
#   Network: 5
#   RLT: 69
#
# Explored 1 nodes (1908653 simplex iterations) in 7200.18 seconds (11149.08 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 235.97 237.231
#
# Time limit reached
# Best objective 2.359703918686e+02, best bound 1.968234620716e+02, gap 16.5898%
# [(0, 1), (1, 5), (2, 47), (3, 4), (4, 7), (5, 2), (6, 8), (7, 9), (8, 10), (9, 11), (10, 70), (11, 6), (20, 0), (47, 3), (70, 20)]
# [(0, 14), (14, 34), (31, 0), (34, 31)]
# [(0, 18), (17, 26), (18, 17), (25, 0), (26, 37), (27, 28), (28, 29), (29, 30), (30, 25), (33, 27), (37, 33)]
# [(0, 23), (16, 71), (21, 35), (23, 21), (35, 68), (54, 0), (55, 54), (68, 16), (71, 55)]
# [(0, 32), (22, 0), (32, 38), (36, 22), (38, 39), (39, 36)]
# [(0, 49), (15, 48), (44, 15), (45, 44), (48, 57), (49, 45), (52, 0), (57, 52)]
# [(0, 56), (19, 24), (24, 0), (51, 72), (53, 51), (56, 53), (69, 19), (72, 69)]
# [(0, 58), (40, 42), (41, 43), (42, 46), (43, 40), (46, 64), (50, 0), (58, 62), (59, 41), (60, 59), (61, 60), (62, 61), (64, 50)]
# [(0, 67), (12, 13), (13, 63), (63, 65), (65, 66), (66, 0), (67, 12)]
# Instância atual: ('Instancias Clusters\\tabelas_2023-11-22.xlsx', 2)
# Set parameter MIPGap to value 0.05
# Set parameter TimeLimit to value 300
# RESTRICOES DE CORTE DE HIPERPLANO
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i5-1235U, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 12 logical processors, using up to 12 threads
#
# Non-default parameters:
# TimeLimit  300
# MIPGap  0.05
#
# Optimize a model with 9668 rows, 11907 columns and 113760 nonzeros
# Model fingerprint: 0x91e7c08e
# Variable types: 7938 continuous, 3969 integer (3969 binary)
# Coefficient statistics:
#   Matrix range     [3e-05, 8e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
#
# Warning: Completing partial solution with 3945 unfixed non-continuous variables out of 3969
# User MIP start produced solution with objective 4 (0.02s)
# Loaded user MIP start with objective 4
#
# Presolve removed 360 rows and 747 columns
# Presolve time: 0.14s
# Presolved: 9308 rows, 11160 columns, 112860 nonzeros
# Variable types: 7380 continuous, 3780 integer (3780 binary)
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: cutoff, 5160 iterations, 0.21 seconds (0.28 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         4.00000    4.00000  0.00%     -    0s
#
# Explored 1 nodes (5160 simplex iterations) in 0.41 seconds (0.52 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 4
#
# Optimal solution found (tolerance 5.00e-02)
# Best objective 4.000000000000e+00, best bound 4.000000000000e+00, gap 0.0000%
# Set parameter MIPGap to value 0.05
# Set parameter TimeLimit to value 7200
# RESTRICOES DE CORTE DE HIPERPLANO
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i5-1235U, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 12 logical processors, using up to 12 threads
#
# Non-default parameters:
# TimeLimit  7200
# MIPGap  0.05
#
# Optimize a model with 5059 rows, 5292 columns and 50644 nonzeros
# Model fingerprint: 0xf49bff8f
# Variable types: 3528 continuous, 1764 integer (1764 binary)
# Coefficient statistics:
#   Matrix range     [3e-05, 8e+03]
#   Objective range  [3e-05, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
#
# Warning: Completing partial solution with 1740 unfixed non-continuous variables out of 1764
# User MIP start produced solution with objective 135.793 (0.01s)
# User MIP start produced solution with objective 135.793 (0.01s)
# Loaded user MIP start with objective 135.793
#
# Presolve removed 161 rows and 332 columns
# Presolve time: 0.07s
# Presolved: 4898 rows, 4960 columns, 50160 nonzeros
# Variable types: 3280 continuous, 1680 integer (1680 binary)
#
# Root relaxation: objective 9.210796e+01, 4299 iterations, 0.17 seconds (0.31 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   92.10796    0   82  135.79276   92.10796  32.2%     -    0s
# H    0     0                     134.8900843   92.10796  31.7%     -    1s
# H    0     0                     133.1454452   92.10796  30.8%     -    1s
# H    0     0                     122.6049827   92.10796  24.9%     -    1s
# H    0     0                     122.0956340  108.21003  11.4%     -    1s
#      0     0  108.21003    0  132  122.09563  108.21003  11.4%     -    1s
# H    0     0                     119.6260429  108.21003  9.54%     -    1s
# H    0     0                     116.4067180  108.65299  6.66%     -    2s
# H    0     0                     115.4822948  108.65299  5.91%     -    2s
#      0     0  108.65299    0  139  115.48229  108.65299  5.91%     -    2s
#      0     0  108.69727    0  137  115.48229  108.69727  5.88%     -    3s
#      0     0  108.70592    0  133  115.48229  108.70592  5.87%     -    3s
#      0     0  108.71794    0  128  115.48229  108.71794  5.86%     -    3s
#      0     0  108.71811    0  127  115.48229  108.71811  5.86%     -    3s
#      0     0  109.40668    0  131  115.48229  109.40668  5.26%     -    5s
# H    0     0                     114.2012230  109.59081  4.04%     -    5s
# H    0     0                     113.3338441  109.59081  3.30%     -    5s
#      0     0  109.59081    0  137  113.33384  109.59081  3.30%     -    5s
#
# Cutting planes:
#   Gomory: 10
#   Lift-and-project: 8
#   Cover: 1
#   Implied bound: 106
#   MIR: 92
#   Flow cover: 26
#   Flow path: 5
#   Network: 2
#   RLT: 3
#
# Explored 1 nodes (15014 simplex iterations) in 5.45 seconds (2.95 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: 113.334 114.201 115.482 ... 135.793
#
# Optimal solution found (tolerance 5.00e-02)
# Best objective 1.133338441298e+02, best bound 1.095908094810e+02, gap 3.3027%
# [(0, 13), (4, 0), (5, 4), (6, 5), (13, 20), (20, 6)]
# [(0, 2), (2, 15), (15, 16), (16, 0)]
# [(0, 3), (1, 0), (3, 1)]
# [(0, 11), (7, 14), (8, 12), (9, 8), (10, 17), (11, 9), (12, 19), (14, 10), (17, 18), (18, 0), (19, 7)]
# Instância atual: ('Instancias Clusters\\tabelas_2023-11-22.xlsx', 1)
# Set parameter MIPGap to value 0.05
# Set parameter TimeLimit to value 300
# RESTRICOES DE CORTE DE HIPERPLANO
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i5-1235U, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 12 logical processors, using up to 12 threads
#
# Non-default parameters:
# TimeLimit  300
# MIPGap  0.05
#
# Optimize a model with 35168 rows, 38988 columns and 595404 nonzeros
# Model fingerprint: 0x48a07c9a
# Variable types: 25992 continuous, 12996 integer (12996 binary)
# Coefficient statistics:
#   Matrix range     [8e-06, 8e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
#
# Warning: Completing partial solution with 12957 unfixed non-continuous variables out of 12996
# User MIP start produced solution with objective 2 (0.10s)
# Loaded user MIP start with objective 2
#
# Presolve removed 666 rows and 1359 columns
# Presolve time: 1.42s
# Presolved: 34502 rows, 37629 columns, 593739 nonzeros
# Variable types: 24975 continuous, 12654 integer (12654 binary)
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root barrier log...
#
# Ordering time: 0.49s
#
# Barrier performed 0 iterations in 2.59 seconds (1.67 work units)
# Barrier solve interrupted - model solved by another algorithm
#
# Concurrent spin time: 0.55s (can be avoided by choosing Method=3)
#
# Solved with dual simplex
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root barrier log...
#
# Ordering time: 3.48s
#
# Barrier statistics:
#  AA' NZ     : 1.953e+06
#  Factor NZ  : 2.937e+07 (roughly 270 MB of memory)
#  Factor Ops : 1.229e+11 (roughly 1 second per iteration)
#  Threads    : 8
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   9.71069230e+02 -1.27079527e+06  1.51e+05 0.00e+00  5.17e+01     7s
#    1   1.54317595e+02 -4.31789541e+05  5.10e+04 1.11e-16  1.55e+01     7s
#    2   1.21947400e+02 -7.05855426e+04  1.32e+04 1.87e-16  3.70e+00     7s
#    3   2.73499365e+01 -3.68856334e+04  2.71e+03 8.33e-17  7.84e-01     7s
#    4   1.61053230e+01 -1.28092897e+04  1.27e+03 9.71e-17  3.50e-01     7s
#    5   7.74048253e+00 -4.57674877e+03  1.82e+02 1.18e-16  7.01e-02     7s
#    6   4.46314542e+00 -1.38340987e+03  7.62e+01 1.12e-16  1.61e-02     7s
#    7   2.82357027e+00 -6.26042675e+02  2.37e+01 8.89e-17  6.01e-03     7s
#    8   2.54295655e+00 -1.53381424e+02  3.80e+00 7.52e-17  1.44e-03     7s
#    9   2.10275031e+00 -2.84264491e+01  3.08e-01 5.61e-17  2.80e-04     7s
#   10   1.81251280e+00  1.68961453e+00  1.42e-03 2.66e-17  1.13e-06     8s
#
# Barrier performed 10 iterations in 8.18 seconds (4.50 work units)
# Objective cutoff exceeded
#
# Concurrent spin time: 2.18s (can be avoided by choosing Method=3)
#
# Solved with barrier
#
# Root relaxation: cutoff, 0 iterations, 8.79 seconds (5.16 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         2.00000    2.00000  0.00%     -   10s
#
# Explored 1 nodes (0 simplex iterations) in 10.45 seconds (6.51 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 2
#
# Optimal solution found (tolerance 5.00e-02)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# Set parameter MIPGap to value 0.05
# Set parameter TimeLimit to value 7200
# RESTRICOES DE CORTE DE HIPERPLANO
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i5-1235U, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 12 logical processors, using up to 12 threads
#
# Non-default parameters:
# TimeLimit  7200
# MIPGap  0.05
#
# Optimize a model with 14435 rows, 8664 columns and 132388 nonzeros
# Model fingerprint: 0x5b3e551d
# Variable types: 5776 continuous, 2888 integer (2888 binary)
# Coefficient statistics:
#   Matrix range     [8e-06, 8e+03]
#   Objective range  [8e-06, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
#
# Warning: Completing partial solution with 2849 unfixed non-continuous variables out of 2888
# User MIP start produced solution with objective 89.6477 (0.08s)
# User MIP start produced solution with objective 89.6477 (0.09s)
# Loaded user MIP start with objective 89.6477
#
# Presolve removed 160 rows and 314 columns
# Presolve time: 0.54s
# Presolved: 14275 rows, 8350 columns, 131730 nonzeros
# Variable types: 5542 continuous, 2808 integer (2808 binary)
#
# Root relaxation: objective 7.264093e+01, 6749 iterations, 0.74 seconds (0.62 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   72.64093    0  134   89.64769   72.64093  19.0%     -    1s
# H    0     0                      87.7772226   72.64093  17.2%     -    2s
# H    0     0                      84.9275487   72.64093  14.5%     -    2s
# H    0     0                      84.2541282   72.64093  13.8%     -    3s
#      0     0   76.90890    0  148   84.25413   76.90890  8.72%     -    4s
# H    0     0                      84.2508304   76.91766  8.70%     -    4s
# H    0     0                      84.0193411   76.91766  8.45%     -    5s
# H    0     0                      83.0992787   76.91766  7.44%     -    7s
# H    0     0                      83.0959809   76.91766  7.44%     -    7s
# H    0     0                      82.9070116   76.91766  7.22%     -    7s
# H    0     0                      82.8791733   76.91766  7.19%     -    7s
#      0     0   76.91766    0  153   82.87917   76.91766  7.19%     -    7s
#      0     0   76.91766    0  154   82.87917   76.91766  7.19%     -    7s
# H    0     0                      82.8640474   76.91766  7.18%     -    8s
# H    0     0                      82.7665404   78.11959  5.61%     -    9s
#      0     0   78.11959    0  173   82.76654   78.11959  5.61%     -    9s
# H    0     0                      82.7632426   78.21454  5.50%     -    9s
#      0     0   78.21454    0  174   82.76324   78.21454  5.50%     -    9s
#      0     0   78.36564    0  175   82.76324   78.36564  5.31%     -    9s
#      0     0   78.38218    0  166   82.76324   78.38218  5.29%     -   10s
#      0     0   78.38375    0  171   82.76324   78.38375  5.29%     -   10s
#      0     0   78.38375    0  176   82.76324   78.38375  5.29%     -   10s
#      0     0   78.58475    0  192   82.76324   78.58475  5.05%     -   10s
#      0     0   78.58475    0  122   82.76324   78.58475  5.05%     -   11s
#      0     0   78.58475    0  179   82.76324   78.58475  5.05%     -   11s
#      0     0   78.58490    0  177   82.76324   78.58490  5.05%     -   11s
#      0     0          -    0        82.76324   78.63187  4.99%     -   11s
#
# Cutting planes:
#   Gomory: 1
#   Lift-and-project: 2
#   Cover: 2
#   Implied bound: 155
#   MIR: 19
#   Flow cover: 29
#   Flow path: 20
#   Zero half: 1
#   Network: 4
#   RLT: 4
#   Relax-and-lift: 3
#
# Explored 1 nodes (22775 simplex iterations) in 11.43 seconds (7.71 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: 82.7632 82.7665 82.864 ... 84.2541
#
# Optimal solution found (tolerance 5.00e-02)
# Best objective 8.276324257387e+01, best bound 7.863186600682e+01, gap 4.9918%
# [(0, 6), (1, 9), (2, 3), (3, 5), (4, 1), (5, 4), (6, 2), (7, 11), (8, 10), (9, 8), (10, 7), (11, 28), (12, 27), (16, 0), (21, 16), (22, 23), (23, 26), (24, 22), (26, 21), (27, 24), (28, 12)]
# [(0, 30), (13, 14), (14, 0), (15, 13), (17, 29), (18, 19), (19, 25), (20, 17), (25, 20), (29, 15), (30, 31), (31, 32), (32, 34), (33, 18), (34, 37), (35, 36), (36, 33), (37, 35)]
# Instância atual: ('Instancias Clusters\\tabelas_2023-11-22.xlsx', 3)
# Set parameter MIPGap to value 0.05
# Set parameter TimeLimit to value 300
# RESTRICOES DE CORTE DE HIPERPLANO
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i5-1235U, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 12 logical processors, using up to 12 threads
#
# Non-default parameters:
# TimeLimit  300
# MIPGap  0.05
#
# Optimize a model with 8720 rows, 10800 columns and 99522 nonzeros
# Model fingerprint: 0x72f8faf2
# Variable types: 7200 continuous, 3600 integer (3600 binary)
# Coefficient statistics:
#   Matrix range     [1e-05, 8e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
#
# Warning: Completing partial solution with 3579 unfixed non-continuous variables out of 3600
# User MIP start produced solution with objective 2 (0.02s)
# Loaded user MIP start with objective 2
#
# Presolve removed 342 rows and 711 columns
# Presolve time: 0.15s
# Presolved: 8378 rows, 10089 columns, 98667 nonzeros
# Variable types: 6669 continuous, 3420 integer (3420 binary)
#
# Root relaxation: cutoff, 3833 iterations, 0.30 seconds (0.54 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         2.00000    2.00000  0.00%     -    0s
#
# Explored 1 nodes (3833 simplex iterations) in 0.48 seconds (0.75 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 2
#
# Optimal solution found (tolerance 5.00e-02)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# Set parameter MIPGap to value 0.05
# Set parameter TimeLimit to value 7200
# RESTRICOES DE CORTE DE HIPERPLANO
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i5-1235U, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 12 logical processors, using up to 12 threads
#
# Non-default parameters:
# TimeLimit  7200
# MIPGap  0.05
#
# Optimize a model with 2855 rows, 2400 columns and 22156 nonzeros
# Model fingerprint: 0xb10f5f53
# Variable types: 1600 continuous, 800 integer (800 binary)
# Coefficient statistics:
#   Matrix range     [1e-05, 8e+03]
#   Objective range  [1e-05, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
#
# Warning: Completing partial solution with 779 unfixed non-continuous variables out of 800
# User MIP start produced solution with objective 70.4678 (0.01s)
# User MIP start produced solution with objective 70.4678 (0.01s)
# Loaded user MIP start with objective 70.4678
#
# Presolve removed 77 rows and 158 columns
# Presolve time: 0.03s
# Presolved: 2778 rows, 2242 columns, 21926 nonzeros
# Variable types: 1482 continuous, 760 integer (760 binary)
#
# Root relaxation: objective 4.779551e+01, 2345 iterations, 0.06 seconds (0.09 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   47.79551    0   64   70.46781   47.79551  32.2%     -    0s
# H    0     0                      66.0631075   47.79551  27.7%     -    0s
# H    0     0                      62.0791222   47.79551  23.0%     -    0s
#      0     0   58.92784    0   71   62.07912   58.92784  5.08%     -    0s
#      0     0   58.96057    0   72   62.07912   58.96057  5.02%     -    0s
#
# Cutting planes:
#   Gomory: 7
#   Cover: 4
#   Implied bound: 110
#   MIR: 75
#   Flow cover: 60
#   Flow path: 10
#   GUB cover: 2
#   Zero half: 1
#   Network: 6
#   RLT: 20
#   Relax-and-lift: 11
#   BQP: 2
#
# Explored 1 nodes (3605 simplex iterations) in 0.34 seconds (0.31 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 62.0791 66.0631 70.4678
#
# Optimal solution found (tolerance 5.00e-02)
# Best objective 6.207912222186e+01, best bound 5.943223515951e+01, gap 4.2637%
# [(0, 5), (1, 3), (2, 4), (3, 2), (4, 7), (5, 1), (7, 0)]
# [(0, 6), (6, 13), (8, 9), (9, 0), (10, 11), (11, 12), (12, 8), (13, 14), (14, 16), (15, 17), (16, 18), (17, 19), (18, 15), (19, 10)]
# Instância atual: ('Instancias Clusters\\tabelas_2023-11-22.xlsx', 4)
# Set parameter MIPGap to value 0.05
# Set parameter TimeLimit to value 300
# RESTRICOES DE CORTE DE HIPERPLANO
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i5-1235U, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 12 logical processors, using up to 12 threads
#
# Non-default parameters:
# TimeLimit  300
# MIPGap  0.05
#
# Optimize a model with 100200 rows, 97200 columns and 2199402 nonzeros
# Model fingerprint: 0x378bfd0d
# Variable types: 64800 continuous, 32400 integer (32400 binary)
# Coefficient statistics:
#   Matrix range     [6e-06, 8e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
#
# Warning: Completing partial solution with 32337 unfixed non-continuous variables out of 32400
# User MIP start produced solution with objective 4 (0.30s)
# Loaded user MIP start with objective 4
#
# Presolve removed 1064 rows and 2145 columns
# Presolve time: 3.60s
# Presolved: 99136 rows, 95055 columns, 2196169 nonzeros
# Variable types: 63187 continuous, 31868 integer (31868 binary)
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root barrier log...
#
#
# Barrier performed 0 iterations in 7.23 seconds (7.80 work units)
# Barrier solve interrupted - model solved by another algorithm
#
# Concurrent spin time: 0.29s (can be avoided by choosing Method=3)
#
# Solved with dual simplex
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root barrier log...
#
# Elapsed ordering time = 5s
# Elapsed ordering time = 20s
# Elapsed ordering time = 25s
# Elapsed ordering time = 30s
# Elapsed ordering time = 36s
# Elapsed ordering time = 40s
# Elapsed ordering time = 45s
# Elapsed ordering time = 52s
# Elapsed ordering time = 55s
# Elapsed ordering time = 60s
# Elapsed ordering time = 66s
# Elapsed ordering time = 70s
# Elapsed ordering time = 75s
# Ordering time: 79.52s
#
# Barrier statistics:
#  AA' NZ     : 8.827e+06
#  Factor NZ  : 4.280e+08 (roughly 3.5 GB of memory)
#  Factor Ops : 6.775e+12 (roughly 60 seconds per iteration)
#  Threads    : 8
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.20569210e+03 -3.19418365e+06  4.06e+05 0.00e+00  7.87e+01    91s
#    1   2.25484201e+03 -1.52008929e+06  1.57e+05 8.89e-04  2.67e+01    91s
#    2   1.93982807e+03 -3.81761275e+05  1.19e+05 4.44e-16  1.68e+01    91s
#    3   3.88373641e+02 -1.19204364e+05  2.03e+04 1.42e-14  3.33e+00    91s
#    4   7.14221828e+01 -7.49764441e+04  6.94e+03 7.11e-14  1.11e+00    91s
#    5   1.08128024e+01 -2.87096901e+04  3.14e+03 2.68e-13  3.77e-01    91s
#    6   7.89428258e+00 -9.56050250e+03  1.11e+03 1.55e-13  1.31e-01    91s
#    7   1.55745405e+00 -3.42281353e+03  2.54e+02 1.24e-14  2.63e-02    91s
#    8   1.71547576e+00 -1.51675304e+03  1.07e+02 2.89e-15  6.52e-03    92s
#    9   2.64148566e+00 -9.51261790e+02  6.61e+01 2.33e-15  3.85e-03    92s
#   10   3.80306907e+00 -1.97009768e+02  4.82e+00 4.58e-16  7.19e-04    92s
#   11   3.74101681e+00 -4.10139918e+01  1.12e+00 3.50e-16  1.55e-04    92s
#   12   3.62441628e+00 -5.33850378e+00  1.92e-01 3.48e-16  3.12e-05    93s
#   13   3.60859110e+00  1.97578203e+00  9.88e-02 3.41e-16  5.67e-06    94s
#   14   3.60263684e+00  3.30973018e+00  1.64e-02 2.25e-16  1.02e-06    95s
#
# Barrier performed 14 iterations in 95.06 seconds (32.45 work units)
# Objective cutoff exceeded
#
# Concurrent spin time: 2.65s
#
# Solved with primal simplex
#
# Root relaxation: cutoff, 49417 iterations, 92.79 seconds (40.75 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         4.00000    4.00000  0.00%     -   97s
#
# Explored 1 nodes (49417 simplex iterations) in 97.87 seconds (47.34 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 4
#
# Optimal solution found (tolerance 5.00e-02)
# Best objective 4.000000000000e+00, best bound 4.000000000000e+00, gap 0.0000%
# Set parameter MIPGap to value 0.05
# Set parameter TimeLimit to value 7200
# RESTRICOES DE CORTE DE HIPERPLANO
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i5-1235U, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 12 logical processors, using up to 12 threads
#
# Non-default parameters:
# TimeLimit  7200
# MIPGap  0.05
#
# Optimize a model with 63611 rows, 43200 columns and 977752 nonzeros
# Model fingerprint: 0x38684688
# Variable types: 28800 continuous, 14400 integer (14400 binary)
# Coefficient statistics:
#   Matrix range     [6e-06, 8e+03]
#   Objective range  [6e-06, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
#
# Warning: Completing partial solution with 14337 unfixed non-continuous variables out of 14400
# User MIP start produced solution with objective 149.64 (0.33s)
# User MIP start produced solution with objective 149.64 (0.37s)
# Loaded user MIP start with objective 149.64
#
# Presolve removed 593 rows and 1048 columns
# Presolve time: 3.57s
# Presolved: 63018 rows, 42152 columns, 973016 nonzeros
# Variable types: 28020 continuous, 14132 integer (14132 binary)
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root barrier log...
#
# Ordering time: 0.88s
#
# Barrier statistics:
#  Dense cols : 177
#  Free vars  : 238
#  AA' NZ     : 4.315e+05
#  Factor NZ  : 4.676e+06 (roughly 60 MB of memory)
#  Factor Ops : 7.457e+09 (less than 1 second per iteration)
#  Threads    : 8
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -2.34577483e+06  5.02374525e+03  4.55e+01 2.26e+04  6.79e+02     6s
#    1  -1.24273760e+06  3.78528881e+04  1.89e+01 1.87e+04  4.26e+02     6s
#    2  -1.15369405e+06  1.66996135e+04  8.35e+00 4.78e+03  1.31e+02     6s
#    3  -7.45417696e+05  6.63437486e+03  3.79e+00 4.24e+03  1.03e+02     6s
#    4  -3.42751614e+05  3.44839178e+03  3.17e-01 7.21e+02  1.96e+01     6s
#    5  -1.26026995e+05  7.24929451e+02  1.68e-03 6.53e+01  3.42e+00     6s
#    6  -5.55492422e+04  3.38181371e+02  6.75e-04 2.28e+01  1.39e+00     6s
#    7  -2.66405031e+04  2.65339367e+02  3.04e-04 5.15e+00  6.02e-01     7s
#    8  -3.62239074e+03  2.36878387e+02  3.65e-05 2.76e-01  8.14e-02     7s
#    9  -1.93932315e+03  2.06117063e+02  1.98e-05 5.13e-02  4.45e-02     7s
#   10  -8.03461505e+02  1.81931611e+02  8.67e-06 1.36e-02  2.04e-02     7s
#   11  -6.09683587e+02  1.58977732e+02  6.81e-06 3.53e-03  1.59e-02     7s
#   12  -1.82893536e+02  1.41098125e+02  2.69e-06 9.22e-04  6.69e-03     7s
#   13  -6.39118496e+00  1.26885123e+02  1.05e-06 3.18e-04  2.75e-03     7s
#   14   6.04818526e+01  1.22114068e+02  4.41e-07 2.03e-04  1.27e-03     8s
#   15   9.27345320e+01  1.14891407e+02  1.56e-07 5.56e-05  4.58e-04     8s
#   16   9.88116121e+01  1.13708448e+02  1.04e-07 3.55e-05  3.08e-04     8s
#   17   1.03628600e+02  1.12674637e+02  6.13e-08 1.87e-05  1.87e-04     8s
#   18   1.08221573e+02  1.11792711e+02  2.44e-08 5.93e-06  7.38e-05     8s
#   19   1.10212719e+02  1.11498698e+02  9.30e-09 2.08e-06  2.66e-05     8s
#   20   1.11177811e+02  1.11348676e+02  2.39e-09 3.76e-07  3.53e-06     8s
#   21   1.11285821e+02  1.11320787e+02  1.14e-09 1.10e-07  7.23e-07     9s
#
# Barrier performed 21 iterations in 8.66 seconds (6.43 work units)
# Barrier solve interrupted - model solved by another algorithm
#
# Concurrent spin time: 1.78s (can be avoided by choosing Method=3)
#
# Solved with primal simplex
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6368    1.1130811e+02   0.000000e+00   0.000000e+00      9s
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6375    1.1130811e+02   0.000000e+00   0.000000e+00      9s
# Extra simplex iterations from dual to original model: 7
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#    10316 DPushes remaining with DInf 0.0000000e+00                 9s
#        0 DPushes remaining with DInf 0.0000000e+00                 9s
#
#      900 PPushes remaining with PInf 0.0000000e+00                 9s
#        0 PPushes remaining with PInf 0.0000000e+00                 9s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 3.1878004e-14      9s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     7550    1.1130811e+02   0.000000e+00   0.000000e+00      9s
#
# ...
#   5616  4029  126.79726   76  568  132.60200  125.68639  5.22%  1356 5793s
#   5617  4029  126.42888   74  572  132.60200  125.68689  5.21%  1356 5796s
#   5619  4031  127.87007  347  581  132.60200  125.68755  5.21%  1355 5804s
# H 5619  3827                     132.4684327  125.69657  5.11%  1355 5831s
#   5621  3828  129.10875  251  558  132.46843  125.69980  5.11%  1355 5841s
#   5622  3829  129.99904  502  561  132.46843  125.70077  5.11%  1354 5848s
#   5623  3829  132.46843  218  552  132.46843  125.70155  5.11%  1354 5854s
#   5624  3830  127.77480  247  575  132.46843  125.70299  5.11%  1354 5864s
#   5625  3831  125.70534   43  561  132.46843  125.70534  5.11%  1354 5872s
#   5626  3831  128.67755  413  579  132.46843  125.70618  5.10%  1353 5884s
#   5627  3832  128.59023  396  586  132.46843  125.70649  5.10%  1353 5893s
#   5628  3833  126.80297  129  585  132.46843  125.70705  5.10%  1353 5899s
#   5629  3833  126.13528   68  599  132.46843  125.70759  5.10%  1353 5903s
#   5630  3834  127.06179  139  593  132.46843  125.70790  5.10%  1352 5908s
#   5631  3835  129.01761  235  601  132.46843  125.70835  5.10%  1352 5912s
#   5632  3835  128.40452  347  593  132.46843  125.70860  5.10%  1352 5920s
# H 5632  3640                     132.3165489  125.71444  4.99%  1352 6104s
#
# Cutting planes:
#   Cover: 4
#   Implied bound: 442
#   Projected implied bound: 5
#   MIR: 155
#   Flow cover: 351
#   Flow path: 120
#   GUB cover: 8
#   Inf proof: 1
#   Zero half: 6
#   Network: 9
#   RLT: 48
#   Relax-and-lift: 12
#
# Explored 5632 nodes (9292201 simplex iterations) in 6104.56 seconds (4549.14 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: 132.317 132.468 132.602 ... 133.845
#
# Optimal solution found (tolerance 5.00e-02)
# Best objective 1.323165489447e+02, best bound 1.257144378141e+02, gap 4.9896%
# [(0, 21), (2, 0), (4, 8), (5, 12), (6, 7), (7, 5), (8, 10), (9, 4), (10, 6), (11, 52), (12, 11), (21, 9), (49, 2), (52, 53), (53, 49)]
# [(0, 50), (1, 0), (3, 1), (22, 24), (23, 25), (24, 23), (25, 51), (26, 41), (41, 42), (42, 48), (47, 3), (48, 47), (50, 54), (51, 26), (54, 22)]
# [(0, 17), (13, 19), (14, 13), (15, 14), (16, 15), (17, 16), (18, 20), (19, 18), (20, 46), (27, 28), (28, 29), (29, 31), (30, 27), (31, 34), (32, 40), (33, 32), (34, 38), (35, 36), (36, 37), (37, 33), (38, 35), (39, 0), (40, 39), (43, 30), (44, 43), (45, 44), (46, 45)]
# Instância atual: ('Instancias Clusters\\tabelas_2024-02-20.xlsx', 4)
# Set parameter MIPGap to value 0.05
# Set parameter TimeLimit to value 300
# RESTRICOES DE CORTE DE HIPERPLANO
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i5-1235U, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 12 logical processors, using up to 12 threads
#
# Non-default parameters:
# TimeLimit  300
# MIPGap  0.05
#
# Optimize a model with 10672 rows, 13068 columns and 129276 nonzeros
# Model fingerprint: 0xe82f3562
# Variable types: 8712 continuous, 4356 integer (4356 binary)
# Coefficient statistics:
#   Matrix range     [2e-05, 8e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
#
# Warning: Completing partial solution with 4333 unfixed non-continuous variables out of 4356
# User MIP start produced solution with objective 2 (0.04s)
# Loaded user MIP start with objective 2
#
# Presolve removed 378 rows and 783 columns
# Presolve time: 0.31s
# Presolved: 10294 rows, 12285 columns, 128331 nonzeros
# Variable types: 8127 continuous, 4158 integer (4158 binary)
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: cutoff, 6462 iterations, 0.70 seconds (0.45 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         2.00000    2.00000  0.00%     -    1s
#
# Explored 1 nodes (6462 simplex iterations) in 1.08 seconds (0.72 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 2
#
# Optimal solution found (tolerance 5.00e-02)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# Set parameter MIPGap to value 0.05
# Set parameter TimeLimit to value 7200
# RESTRICOES DE CORTE DE HIPERPLANO
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i5-1235U, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 12 logical processors, using up to 12 threads
#
# Non-default parameters:
# TimeLimit  7200
# MIPGap  0.05
#
# Optimize a model with 3603 rows, 2904 columns and 28772 nonzeros
# Model fingerprint: 0x934fad7a
# Variable types: 1936 continuous, 968 integer (968 binary)
# Coefficient statistics:
#   Matrix range     [2e-05, 8e+03]
#   Objective range  [2e-05, 9e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
#
# Warning: Completing partial solution with 945 unfixed non-continuous variables out of 968
# User MIP start produced solution with objective 55.4416 (0.02s)
# User MIP start produced solution with objective 55.4416 (0.02s)
# Loaded user MIP start with objective 55.4416
#
# Presolve removed 85 rows and 174 columns
# Presolve time: 0.16s
# Presolved: 3518 rows, 2730 columns, 28518 nonzeros
# Variable types: 1806 continuous, 924 integer (924 binary)
#
# Root relaxation: objective 3.334411e+01, 1967 iterations, 0.14 seconds (0.09 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   33.34411    0   72   55.44164   33.34411  39.9%     -    0s
#      0     0   43.41648    0   80   55.44164   43.41648  21.7%     -    0s
# H    0     0                      51.1299645   43.42064  15.1%     -    0s
#      0     0   43.46694    0   91   51.12996   43.46694  15.0%     -    1s
#      0     0   43.93314    0   88   51.12996   43.93314  14.1%     -    1s
# H    0     0                      47.7010044   43.93671  7.89%     -    1s
# H    0     0                      47.5125918   43.93671  7.53%     -    1s
# H    0     0                      47.3794125   43.93671  7.27%     -    1s
#      0     0   43.95614    0   95   47.37941   43.95614  7.23%     -    1s
#      0     0   43.96398    0  100   47.37941   43.96398  7.21%     -    1s
#      0     0   43.96403    0  102   47.37941   43.96403  7.21%     -    1s
# H    0     0                      47.0260684   43.96403  6.51%     -    2s
#      0     0   44.26806    0  117   47.02607   44.26806  5.86%     -    2s
#      0     0   44.26806    0   63   47.02607   44.26806  5.86%     -    2s
#      0     0   44.26806    0   90   47.02607   44.26806  5.86%     -    2s
#      0     0   44.26806    0   96   47.02607   44.26806  5.86%     -    2s
#      0     0   44.26806    0  107   47.02607   44.26806  5.86%     -    2s
#      0     0   44.26806    0  103   47.02607   44.26806  5.86%     -    2s
#      0     0   44.26806    0  108   47.02607   44.26806  5.86%     -    2s
#      0     0   44.35889    0  104   47.02607   44.35889  5.67%     -    2s
#      0     0   44.36473    0  111   47.02607   44.36473  5.66%     -    3s
#      0     0   44.36948    0  109   47.02607   44.36948  5.65%     -    3s
#      0     0   44.41622    0  112   47.02607   44.41622  5.55%     -    3s
#      0     0   44.41622    0   63   47.02607   44.41622  5.55%     -    3s
#      0     0   44.41622    0  100   47.02607   44.41622  5.55%     -    3s
#      0     0   44.41622    0  102   47.02607   44.41622  5.55%     -    3s
#      0     0   44.41622    0  102   47.02607   44.41622  5.55%     -    3s
#      0     0   44.41622    0  103   47.02607   44.41622  5.55%     -    3s
#      0     0   44.41622    0   99   47.02607   44.41622  5.55%     -    3s
#      0     0   44.41753    0  106   47.02607   44.41753  5.55%     -    3s
#      0     0   44.41956    0  102   47.02607   44.41956  5.54%     -    3s
#      0     0   44.43213    0  106   47.02607   44.43213  5.52%     -    3s
#      0     0   44.43876    0  108   47.02607   44.43876  5.50%     -    3s
#      0     0   44.43924    0  106   47.02607   44.43924  5.50%     -    3s
#      0     0   44.51388    0  106   47.02607   44.51388  5.34%     -    4s
#      0     0   44.55890    0  100   47.02607   44.55890  5.25%     -    4s
#      0     0   44.55937    0  102   47.02607   44.55937  5.25%     -    4s
#      0     0          -    0        47.02607   44.71485  4.91%     -    4s
#
# Cutting planes:
#   Lift-and-project: 3
#   Cover: 3
#   Implied bound: 109
#   MIR: 46
#   Flow cover: 42
#   Flow path: 33
#   Zero half: 3
#   Network: 2
#   RLT: 34
#   Relax-and-lift: 4
#   BQP: 3
#
# Explored 1 nodes (12328 simplex iterations) in 4.48 seconds (1.43 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 5: 47.0261 47.3794 47.5126 ... 55.4416
#
# Optimal solution found (tolerance 5.00e-02)
# Best objective 4.702606838362e+01, best bound 4.471485498594e+01, gap 4.9147%
# [(0, 2), (1, 0), (2, 9), (4, 13), (5, 6), (6, 4), (7, 5), (8, 7), (9, 8), (10, 1), (11, 10), (12, 17), (13, 14), (14, 15), (15, 21), (16, 12), (17, 11), (18, 16), (19, 18), (20, 19), (21, 20)]
# [(0, 3), (3, 0)]
# Instância atual: ('Instancias Clusters\\tabelas_2024-02-20.xlsx', 3)
# Set parameter MIPGap to value 0.05
# Set parameter TimeLimit to value 300
# RESTRICOES DE CORTE DE HIPERPLANO
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i5-1235U, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 12 logical processors, using up to 12 threads
#
# Non-default parameters:
# TimeLimit  300
# MIPGap  0.05
#
# Optimize a model with 16567 rows, 19683 columns and 227916 nonzeros
# Model fingerprint: 0x2e9c9546
# Variable types: 13122 continuous, 6561 integer (6561 binary)
# Coefficient statistics:
#   Matrix range     [1e-05, 8e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
#
# Warning: Completing partial solution with 6534 unfixed non-continuous variables out of 6561
# User MIP start produced solution with objective 1 (0.06s)
# Loaded user MIP start with objective 1
#
# Presolve removed 468 rows and 963 columns
# Presolve time: 0.52s
# Presolved: 16099 rows, 18720 columns, 226746 nonzeros
# Variable types: 12402 continuous, 6318 integer (6318 binary)
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
# Concurrent spin time: 0.03s
#
# Solved with dual simplex
#
# Root relaxation: infeasible, 61 iterations, 0.27 seconds (0.13 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 infeasible    0         1.00000    1.00000  0.00%     -    0s
#
# Explored 1 nodes (61 simplex iterations) in 0.92 seconds (0.61 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 5.00e-02)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Set parameter MIPGap to value 0.05
# Set parameter TimeLimit to value 7200
# RESTRICOES DE CORTE DE HIPERPLANO
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i5-1235U, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 12 logical processors, using up to 12 threads
#
# Non-default parameters:
# TimeLimit  7200
# MIPGap  0.05
#
# Optimize a model with 4488 rows, 2187 columns and 25351 nonzeros
# Model fingerprint: 0x80bd09d2
# Variable types: 1458 continuous, 729 integer (729 binary)
# Coefficient statistics:
#   Matrix range     [1e-05, 8e+03]
#   Objective range  [1e-05, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
#
# Warning: Completing partial solution with 702 unfixed non-continuous variables out of 729
# User MIP start produced solution with objective 47.0124 (0.02s)
# User MIP start produced solution with objective 47.0124 (0.02s)
# Loaded user MIP start with objective 47.0124
#
# Presolve removed 53 rows and 107 columns
# Presolve time: 0.16s
# Presolved: 4435 rows, 2080 columns, 24492 nonzeros
# Variable types: 1378 continuous, 702 integer (702 binary)
#
# Root relaxation: objective 3.377685e+01, 1962 iterations, 0.19 seconds (0.09 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   33.77685    0   83   47.01239   33.77685  28.2%     -    0s
# H    0     0                      46.5985332   33.77685  27.5%     -    0s
# H    0     0                      45.6590553   33.77685  26.0%     -    0s
# H    0     0                      45.6368107   33.77685  26.0%     -    0s
#      0     0   41.04073    0   92   45.63681   41.04073  10.1%     -    1s
# H    0     0                      45.1049441   41.04224  9.01%     -    1s
# H    0     0                      44.9420886   41.04224  8.68%     -    1s
# H    0     0                      44.6697144   41.04224  8.12%     -    1s
#      0     0   41.04224    0   90   44.66971   41.04224  8.12%     -    1s
#      0     0   41.25852    0   99   44.66971   41.25852  7.64%     -    1s
# H    0     0                      44.5613221   41.28164  7.36%     -    1s
#      0     0   41.28164    0   97   44.56132   41.28164  7.36%     -    1s
#      0     0   41.28308    0   98   44.56132   41.28308  7.36%     -    1s
#      0     0   41.33219    0  100   44.56132   41.33219  7.25%     -    2s
#      0     0   41.33930    0  104   44.56132   41.33930  7.23%     -    2s
#      0     0   41.34283    0  101   44.56132   41.34283  7.22%     -    2s
#      0     0   41.34334    0  101   44.56132   41.34334  7.22%     -    2s
#      0     0   41.36964    0  103   44.56132   41.36964  7.16%     -    2s
#      0     0   41.37483    0  101   44.56132   41.37483  7.15%     -    3s
#      0     0   41.37778    0  101   44.56132   41.37778  7.14%     -    3s
#      0     0   41.37817    0  102   44.56132   41.37817  7.14%     -    3s
#      0     0   41.39319    0  103   44.56132   41.39319  7.11%     -    3s
#      0     0   41.39475    0  108   44.56132   41.39475  7.11%     -    3s
#      0     0   41.40019    0  109   44.56132   41.40019  7.09%     -    3s
#      0     0   41.40182    0  108   44.56132   41.40182  7.09%     -    3s
#      0     0   41.41242    0  108   44.56132   41.41242  7.07%     -    3s
#      0     0   41.41258    0  108   44.56132   41.41258  7.07%     -    3s
# H    0     0                      44.4971582   41.41268  6.93%     -    4s
#      0     2   41.41268    0  108   44.49716   41.41268  6.93%     -    4s
#     15    26   41.60975    4  100   44.49716   41.49237  6.75%   260    5s
# H  120   125                      44.0509262   41.61360  5.53%   116    5s
# H  125   125                      43.9794704   41.61360  5.38%   113    5s
#   1489  1369   43.18891   19   70   43.97947   41.65274  5.29%  67.6   10s
#
# Cutting planes:
#   Gomory: 1
#   Lift-and-project: 8
#   Implied bound: 167
#   MIR: 64
#   Flow cover: 97
#   Flow path: 95
#   Zero half: 1
#   Network: 8
#   RLT: 1
#   Relax-and-lift: 2
#
# Explored 1942 nodes (147189 simplex iterations) in 13.08 seconds (6.77 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: 43.9795 44.0509 44.4972 ... 46.5985
#
# Optimal solution found (tolerance 5.00e-02)
# Best objective 4.397947035227e+01, best bound 4.190254430417e+01, gap 4.7225%
# [(0, 20), (1, 2), (2, 3), (3, 0), (4, 1), (5, 4), (6, 5), (7, 9), (8, 7), (9, 21), (10, 15), (11, 17), (12, 25), (13, 14), (14, 12), (15, 16), (16, 11), (17, 18), (18, 19), (19, 13), (20, 10), (21, 6), (22, 8), (23, 22), (24, 23), (25, 26), (26, 24)]
